# %% [markdown]
# <font color='darkred'> Unless otherwise noted, **this notebook will not be reviewed or autograded.**</font> You are welcome to use it for scratchwork, but **only the files listed in the exercises will be checked.**
#
# ---

# %% [markdown]
# # Background
#
# Before we move into the exercises, we'll cover some background information to get you started.

# %%
import numpy as np
import pandas as pd
import requests
import re

# %% [markdown]
# ## Markov Chain Simple Example

# %% [markdown]
# Markov chains are a way of representing how systems change over time. The main concept behind Markov chains are that they are memoryless, meaning that the next state of a process only depends on the previous state.

# %% [markdown]
# ![image](https://upload.wikimedia.org/wikipedia/commons/7/7a/Markov_Chain_weather_model_matrix_as_a_graph.png)
#
# The way to read the Markov chain above from [Wikipedia](https://commons.wikimedia.org/w/index.php?curid=25300524) is:
# * If I am currently in the sunny state, there is a 10% chance I will go to the rainy state and a 90% chance I will remain in the sunny state
# * If I am currently in the rainy state, there is an 50% chance I will go to the sunny state and a 50% chance I will remain in the rainy state

# %% [markdown]
# ## Transition Matrices

# %% [markdown]
# This is what our **transition matrix** will look like for the Markov chain diagram above. Take a minute to interpret the rows and columns of this matrix.

# %%
P = np.asarray([.9, .1, .5, .5]).reshape(2,2)
states = ['sunny', 'rainy']

pd.DataFrame(P, index=states, columns=states)
# Out:
#        sunny  rainy
# sunny    0.9    0.1
# rainy    0.5    0.5

# %% [markdown]
# ## Predict Tomorrow's Weather

# %% [markdown]
# Let's say it's sunny today, we can represent that as:
#
# `today = [1, 0]`
#
# **Predict tomorrow's weather using what you know about today and the transition matrix.**

# %%
today = [1, 0]

tomorrow = np.dot(today, P)
tomorrow
# Out:
# array([0.9, 0.1])

# %% [markdown]
# In this example, there is a 90% chance it will remain sunny tomorrow, and a 10% chance it'll be rainy.

# %% [markdown]
# **Predict the day after tomorrow's weather.**

# %%
# Method 1: Multiply tomorrow's weather by the transition matrix
day_after = np.dot(tomorrow, P)
day_after
# Out:
# array([0.86, 0.14])

# %%
# Method 2: Multiply today's weather by the transition matrix^2
day_after = np.dot(today, np.linalg.matrix_power(P, 2))
day_after
# Out:
# array([0.86, 0.14])

# %% [markdown]
# ## Text Generation
#
# Markov chains can also be used for very basic text generation. **Think about every word in a corpus as a state.** We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain. In this exercise, you'll create a text generator which uses only this concept.

# %% [markdown]
# ## Read in some text to imitate

# %% [markdown]
# We are going to generate some text in the style of inspirational quotes, so let's first read in the data.

# %%
url = 'https://raw.githubusercontent.com/leontoddjohnson/datasets/main/text/inspiration_quotes.txt'

content = requests.get(url)
quotes_raw = content.text

print(quotes_raw[:1000])
# Out:
# “Healing comes from taking responsibility: to realize that it is you - and no one else - that creates your thoughts, your feelings, and your actions.” —Peter Shepherd
#
# “Life is a journey and if you fall in love with the journey you will be in love forever.” —Peter Hagerty
#
# “When you return to your old hometown, you find it wasn’t the town you missed, but your childhood.” —Earl Wilson
#
# “As we grow old, the beauty steals inward.” —Ralph Waldo Emerson
#
# “Life begins as a quest of the child for the man, and ends as a journey by the man to rediscover the child.” —Sam Ewing
#
# Happiness
# “Ultimately your greatest teacher is to live with an open heart.” —Emmanuel (Pat Rodegast)
#
# “Doing what you like is freedom. Liking what you do is happiness.” —Frank Tyger
#
# “We forge the chains we wear in life.” —Charles Dickens
#
# happiness quote
# “If you look to others for fulfillment, you will never be fulfilled. If your happiness depends on money, you will never be happy with yourself. Be content with what you

# %% [markdown]
# ## Clean up the text data
#
# There are many ways to clean up data before building a text generator. In this case, we'll try to at least just extract the quotes themselves.
#
# *After you complete the exercises, feel free to adjust this section of the process ...*

# %%
quotes = quotes_raw.replace('\n', ' ')
quotes = re.split("[“”]", quotes)   # split on the unique “ characters
quotes[:3]
# Out:
# ['',
#  'Healing comes from taking responsibility: to realize that it is you - and no one else - that creates your thoughts, your feelings, and your actions.',
#  ' —Peter Shepherd  ']

# %%
# skip the first one, and capture every other element
quotes = quotes[1::2]
quotes[:3]
# Out:
# ['Healing comes from taking responsibility: to realize that it is you - and no one else - that creates your thoughts, your feelings, and your actions.',
#  'Life is a journey and if you fall in love with the journey you will be in love forever.',
#  'When you return to your old hometown, you find it wasn’t the town you missed, but your childhood.']

# %%
# create one long corpus of text
corpus = ' '.join(quotes)

# remove long whitespaces (see regex101.com)
corpus = re.sub(r"\s+", " ", corpus)

# remove leading/trailing whitespaces
corpus = corpus.strip()

corpus[:200]
# Out:
# 'Healing comes from taking responsibility: to realize that it is you - and no one else - that creates your thoughts, your feelings, and your actions. Life is a journey and if you fall in love with the '

# %% [markdown]
# In general, this version of `corpus` should work just fine!

# %% [markdown]
# # Exercises
#
# In these exercises, you'll build a `MarkovText` object that takes in a `corpus` of text, and has the capability to generate text using the Markov Property.

# %%
from apputil import *

# %% [markdown]
# ## Exercise 1: Build a Transition Dictionary

# %% [markdown]
# Update the `get_term_dict` method to build a term dictionary of Markov states with the following traits:
#
# * The keys should be (unique) tokens in the corpus
# * For each key, the value should be a `list` of all the tokens that follow that key
#     - E.g., if my total corpus is "Astrid is very kind, is she not?", then my dictionary should include `{... "is": ["very", "she"] ...}`.
#     - Decide whether or not to include duplicates (i.e., *every* iteration) in these lists. Then, explain why or why not.
#
# *Hint: You'll likely want to use [`defaultdict(list)`](https://realpython.com/python-defaultdict/#understanding-the-python-defaultdict-type) here.*

# %% [markdown]
# Apply the function to the quotes above. Your final output should look something like this:
#
# ```python
# {
#     'Healing': ['comes'],
#     'comes': ['from', 'the', 'the', ...],
#     'from': ['taking', 'aesthetic', 'a'],
#     ...
# }
# ```

# %%
text_gen = MarkovText(corpus, k=1)

text_gen.get_term_dict()
# Out:
# {'Healing': ['comes'],
#  'comes': ['from', 'from'],
#  'from': ['taking',
#   'aesthetic',
#   'a',
#   'having',
#   'not',
#   'the',
#   'the',
#   'it.',
#   'our',
#   'experience',
#   'experience.',
#   'avoiding',
#   'our'],
#  'taking': ['responsibility:', 'it.'],
#  'responsibility:': ['to'],
#  'to': ['realize',
#   'your',
#   'rediscover',
#   'live',
#   'others',
#   'you.',
#   'be',
#   'be',
#   'pay',
#   'give',
#   'share',
#   'have',
#   'draw',
#   'think',
#   'you;',
#   'go',
#   'the',
#   'obtain',
#   'mourn',
#   'live',
#   'a',
#   'make',
#   'forgive.',
#   'take',
#   'do.',
#   'be',
#   'be',
#   'change',
#   'control',
#   'an',
#   'take',
#   'accept',
#   'change',
#   'know',
#   'win,',
#   'be',
#   'succeed,',
#   'live',
#   'the',
#   'order,',
#   'clarity.',
#   'get',
#   'be',
#   'shine',
#   'manifest',
#   'do',
#   'work',
#   'work',
#   'think',
#   'play',
#   'read',
#   'be',
#   'happiness',
#   'love',
#   'share',
#   'be',
#   'laugh',
#   'dream',
#   'a',
#   'make',
#   'others;',
#   'prove',
#   'learn',
#   'focus',
#   'anything,',
#   'accept',
#   'change',
#   'know',
#   'treat',
#   'charge'],
#  'realize': ['that', 'there', 'it.', 'you'],
#  'that': ['it',
#   'creates',
#   'commands',
#   'tends',
#   'people',
#   'we',
#   'has',
#   'state',
#   'momentary',
#   'irritates',
#   'we',
#   'we',
#   'we',
#   'we',
#   'most',
#   'other',
#   'is',
#   'sets',
#   'is',
#   'we',
#   'we’re',
#   'we',
#   'take',
#   'you',
#   'bring',
#   'everything',
#   'nothing',
#   'it',
#   'makes',
#   'makes',
#   'he'],
#  'it': ['is',
#   'wasn’t',
#   'is',
#   'certainly',
#   'does',
#   'were',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'worth',
#   'becomes',
#   'is',
#   'either'],
#  'is': ['you',
#   'a',
#   'to',
#   'freedom.',
#   'happiness.',
#   'nothing',
#   'a',
#   'perfect',
#   'no',
#   'who',
#   'who',
#   'sufficient',
#   '‘out',
#   'the',
#   'the',
#   'not',
#   'the',
#   'when',
#   'settled,',
#   'the',
#   'found',
#   'to',
#   'unavoidable,',
#   'unavoidable.',
#   'all',
#   'not',
#   'not',
#   'neither',
#   'a',
#   'an',
#   'nothing',
#   'far',
#   'not',
#   'appreciating',
#   'that',
#   'but',
#   'an',
#   'beauty,',
#   'bliss,',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'sorrow,',
#   'a',
#   'a',
#   'a',
#   'an',
#   'luck,',
#   'too',
#   'life,',
#   'getting',
#   'wanting',
#   'the',
#   'being',
#   'looking',
#   'happiness',
#   'knowing',
#   'taking',
#   'in',
#   'not',
#   'measured',
#   'no',
#   'a',
#   'perfect',
#   'that',
#   'our',
#   'nothing',
#   'within',
#   'not',
#   'in',
#   'a',
#   'only',
#   'not',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'too',
#   'the',
#   'hitching',
#   'not',
#   'unpopular',
#   'a',
#   'being',
#   'the',
#   'made',
#   'where',
#   'the',
#   'its',
#   'always',
#   'missing',
#   'the',
#   'a',
#   'not',
#   'required',
#   'really',
#   'like'],
#  'you': ['-',
#   'fall',
#   'will',
#   'return',
#   'find',
#   'missed,',
#   'like',
#   'do',
#   'look',
#   'will',
#   'will',
#   'have;',
#   'realize',
#   'in',
#   'need',
#   'want',
#   'think',
#   'should',
#   'are.',
#   'acquire,',
#   'confidence,',
#   'joy.',
#   'have.',
#   'want.',
#   'start',
#   'arrive',
#   'love.',
#   'present',
#   'want',
#   'want',
#   'want.',
#   'have.',
#   'want.',
#   'get.',
#   'see.',
#   'not',
#   'won’t',
#   'do',
#   'love,',
#   'never',
#   'have',
#   'have',
#   'take,',
#   'have',
#   'lack.',
#   'have,',
#   'would',
#   'did',
#   'realize',
#   'contain',
#   'seek.',
#   'worried',
#   'makes',
#   'stronger.',
#   'were',
#   'well',
#   'are',
#   'are'],
#  '-': ['and',
#   'that',
#   'not',
#   'it’s',
#   'it’s',
#   'even',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it',
#   'it'],
#  'and': ['no',
#   'your',
#   'if',
#   'ends',
#   'inspires',
#   'a',
#   'children',
#   'a',
#   'a',
#   'others',
#   'respect.',
#   'gratitude.',
#   'the',
#   'end',
#   'the',
#   'God.',
#   'it',
#   'ease',
#   'freedom.',
#   'body',
#   'earnestly.',
#   'take',
#   'the',
#   'equanimity.',
#   'the',
#   'women',
#   'their',
#   'one',
#   'wanting',
#   'creativity.',
#   'happiness',
#   'seeing',
#   'happiness',
#   'disturbs',
#   'watch',
#   'judge',
#   'watch',
#   'embrace',
#   'the',
#   'more.',
#   'creates',
#   'loving',
#   'then',
#   'chaos,',
#   'that',
#   'be',
#   'easy',
#   'you’ll',
#   'be',
#   'be',
#   'be',
#   'then',
#   'in',
#   'lack',
#   'personal',
#   'we',
#   'wisdom',
#   'meaning',
#   'yet,'],
#  'no': ['one', 'such', 'regret.', 'stress'],
#  'one': ['else', 'man', 'door', 'that', 'thing', 'gives'],
#  'else': ['-', 'for'],
#  'creates': ['your', 'a'],
#  'your': ['thoughts,',
#   'feelings,',
#   'actions.',
#   'old',
#   'childhood.',
#   'greatest',
#   'happiness',
#   'thoughts,',
#   'energy,',
#   'hopes.',
#   'work,',
#   'past',
#   'THOUGHTS,',
#   'WORDS.',
#   'WORDS,',
#   'ACTIONS.',
#   'ACTIONS,',
#   'HABITS.',
#   'HABITS,',
#   'VALUES.',
#   'VALUES,',
#   'wagon',
#   'breath',
#   'time',
#   'life.',
#   'dysfunction.'],
#  'thoughts,': ['your', 'liberates'],
#  'feelings,': ['and'],
#  'actions.': ['Life'],
#  'Life': ['is',
#   'begins',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'isn’t',
#   'is'],
#  'a': ['journey',
#   'quest',
#   'journey',
#   'gift',
#   'problem',
#   'gift',
#   'goal',
#   'little',
#   'little',
#   'substantial',
#   'couple',
#   'wife',
#   'corner',
#   'book',
#   'friend,',
#   'nap',
#   'more',
#   'station',
#   'manner',
#   'single',
#   'little',
#   'worthy',
#   'form',
#   'happy',
#   'measure',
#   'stage,',
#   'play...',
#   'dream,',
#   'challenge,',
#   'duty,',
#   'game,',
#   'promise,',
#   'song,',
#   'struggle,',
#   'tragedy,',
#   'living',
#   'life',
#   'meal',
#   'feast,',
#   'house',
#   'home,',
#   'stranger',
#   'friend.',
#   'vision',
#   'gift',
#   'child',
#   'curve',
#   'life',
#   'star.',
#   'true',
#   'comparative',
#   'kiss',
#   'kind',
#   'heartfelt',
#   'flower,',
#   'pebble',
#   'person',
#   'cloud',
#   'stranger,',
#   'disorganized',
#   'heaven',
#   'hell',
#   'blade',
#   'mysterious,',
#   'waste',
#   'good',
#   'vegetarian.',
#   'series'],
#  'journey': ['and', 'you', 'by'],
#  'if': ['you', 'this', 'it', 'you’ll', 'you’ll', 'we', 'we', 'you'],
#  'fall': ['in'],
#  'in': ['love',
#   'love',
#   'life.',
#   'the',
#   'its',
#   'eliminating',
#   'fact',
#   'finishing',
#   'doing',
#   'the',
#   'harmony',
#   'harmony',
#   'his',
#   'the',
#   'love',
#   'him/her',
#   'many',
#   'the',
#   'the',
#   'the',
#   'life',
#   'life',
#   'the',
#   'some',
#   'everyone.',
#   'life',
#   'being',
#   'our',
#   'any',
#   'the',
#   'the',
#   'the',
#   'itself',
#   'our',
#   'itself.'],
#  'love': ['with', 'forever.', 'with', 'is', 'and', 'and'],
#  'with': ['the',
#   'an',
#   'yourself.',
#   'what',
#   'you.',
#   'them.',
#   'what',
#   'love,',
#   'the',
#   'which',
#   'intention.',
#   'abandon.',
#   'no',
#   'patience',
#   'himself',
#   'the',
#   'that',
#   'what',
#   'it.',
#   'glory.'],
#  'the': ['journey',
#   'town',
#   'beauty',
#   'child',
#   'man,',
#   'man',
#   'child.',
#   'chains',
#   'way',
#   'world',
#   'universe',
#   'recipe',
#   'monthly',
#   'need',
#   'problem',
#   'problem.',
#   'spiritual',
#   'meaning',
#   'purpose',
#   'whole',
#   'denial',
#   'journey,',
#   'destination.',
#   'life',
#   'candle',
#   'heavens,',
#   'circumstances',
#   'adaptability',
#   'edge.',
#   'past,',
#   'future.',
#   'past,',
#   'future,',
#   'present',
#   'back.',
#   'ear.',
#   'word',
#   'stress',
#   'universe.',
#   'world’s',
#   'men',
#   'closed',
#   'one',
#   'first',
#   'enjoyment',
#   'achievement',
#   'joyful',
#   'past',
#   'future.',
#   'experience',
#   'absolute',
#   'same',
#   'disturbed',
#   'comfortable.',
#   'serenity',
#   'things',
#   'courage',
#   'things',
#   'wisdom',
#   'difference.',
#   'light',
#   'fullness',
#   'real',
#   'doing',
#   'end',
#   'final',
#   'doing',
#   'things',
#   'places',
#   'route',
#   'people',
#   'world,',
#   'midst',
#   'universe',
#   'world.',
#   'glory',
#   'same.',
#   'price',
#   'source',
#   'secret',
#   'fountain',
#   'road',
#   'nourishment',
#   'soul',
#   'music',
#   'heart',
#   'popular',
#   'dizziness',
#   'little',
#   'things',
#   'truly',
#   'street',
#   'tire',
#   'distance',
#   'sky',
#   'opportunity.',
#   'breaths',
#   'moments',
#   'things',
#   'best',
#   'tomorrow',
#   'abundance',
#   'joys',
#   'things',
#   'things',
#   'difference.',
#   'feeling',
#   'gratefulness',
#   'first',
#   'ending',
#   'very',
#   'movie,',
#   'hundreds',
#   'context',
#   'whole'],
#  'will': ['be',
#   'never',
#   'never',
#   'not',
#   'be',
#   'become',
#   'simply',
#   'be',
#   'be',
#   'tend...when',
#   'never',
#   'be'],
#  'be': ['in',
#   'fulfilled.',
#   'happy',
#   'happy,',
#   'just',
#   'traveled',
#   'lit',
#   'shortened.',
#   'quiet,',
#   'comfort',
#   'without',
#   'happy,',
#   'happy,',
#   'thou',
#   'true.',
#   'these',
#   'friendly',
#   'loved',
#   'selfish',
#   'dire',
#   'grateful.',
#   'appreciative.',
#   'thankful',
#   'happy!',
#   'content',
#   'filled',
#   'apparent'],
#  'forever.': ['When'],
#  'When': ['you', 'you', 'one'],
#  'return': ['to'],
#  'old': ['hometown,'],
#  'hometown,': ['you'],
#  'find': ['it', 'it,'],
#  'wasn’t': ['the'],
#  'town': ['you'],
#  'missed,': ['but'],
#  'but': ['your',
#   'a',
#   'in',
#   'it',
#   'to',
#   'through',
#   'often',
#   'a',
#   'I',
#   'the',
#   'our',
#   'by',
#   'very',
#   'are',
#   'the'],
#  'childhood.': ['As'],
#  'As': ['we', 'long', 'we'],
#  'we': ['grow',
#   'wear',
#   'experience',
#   'already',
#   'look',
#   'do',
#   'let',
#   'get,',
#   'make',
#   'give.',
#   'have',
#   'achieve,',
#   'go,',
#   'take',
#   'share',
#   'are',
#   'are',
#   'let',
#   'unconsciously',
#   'are',
#   'don’t',
#   'make',
#   'think',
#   'confront',
#   'need',
#   'become',
#   'can',
#   'know',
#   'choose',
#   'will',
#   'find',
#   'seek',
#   'will',
#   'choose',
#   'experience',
#   'must'],
#  'grow': ['old,'],
#  'old,': ['the'],
#  'beauty': ['steals', 'with'],
#  'steals': ['inward.'],
#  'inward.': ['Life'],
#  'begins': ['as'],
#  'as': ['a',
#   'a',
#   'a',
#   'this',
#   'if',
#   'they',
#   'if',
#   'if',
#   'children',
#   'we',
#   'parallel',
#   'though',
#   'a'],
#  'quest': ['of'],
#  'of': ['the',
#   'the',
#   'good',
#   'real',
#   'living',
#   'emotional',
#   'living',
#   'traveling.',
#   'life,',
#   'human',
#   'life.',
#   'candles',
#   'the',
#   'health',
#   'us',
#   'energy',
#   'who',
#   'which',
#   'which',
#   'darkness,',
#   'the',
#   'happiness',
#   'one’s',
#   'consciousness',
#   'one’s',
#   'wanting',
#   'loving',
#   'ourselves.',
#   'life.',
#   'our',
#   'what',
#   'it.',
#   'our',
#   'movement',
#   'you.',
#   'the',
#   'God.',
#   'God',
#   'us;',
#   'success',
#   'power',
#   'perpetual',
#   'wisdom',
#   'the',
#   'the',
#   'moral',
#   'high',
#   'freedom.',
#   'life',
#   'the',
#   'a',
#   'because',
#   'what',
#   'what',
#   'hell,',
#   'heaven.',
#   'nature',
#   'illusion',
#   'grass,',
#   'time;',
#   'him',
#   'movie',
#   'the',
#   'the',
#   'individual',
#   'the'],
#  'child': ['for', 'of'],
#  'for': ['the',
#   'fulfillment,',
#   'our',
#   'you',
#   'happiness',
#   'your',
#   'understanding,',
#   'love,',
#   'those',
#   'every',
#   'both',
#   'the',
#   'life’s',
#   'forgiveness',
#   'us.',
#   'it.',
#   'they',
#   'they',
#   'they',
#   'they',
#   'they',
#   'today,',
#   'tomorrow.',
#   'our',
#   'us',
#   'right',
#   'the',
#   'the',
#   'that,',
#   'the',
#   'your',
#   'your'],
#  'man,': ['and'],
#  'ends': ['as'],
#  'by': ['the',
#   'my',
#   'creditors',
#   'being',
#   'sadness.',
#   'what',
#   'what',
#   'the',
#   'the',
#   'measuring',
#   'the',
#   'the'],
#  'man': ['to', 'has', 'in', 'who'],
#  'rediscover': ['the'],
#  'child.': ['Ultimately'],
#  'Ultimately': ['your'],
#  'greatest': ['teacher'],
#  'teacher': ['is'],
#  'live': ['with', 'in', 'forever,', 'as', 'up'],
#  'an': ['open',
#   'activity',
#   'illusion.',
#   'opportunity,',
#   'adventure,',
#   'understanding',
#   'angry'],
#  'open': ['heart.'],
#  'heart.': ['Doing'],
#  'Doing': ['what'],
#  'what': ['you',
#   'you',
#   'you',
#   'should',
#   'should',
#   'you',
#   'you',
#   'you',
#   'they’ve',
#   'you',
#   'you',
#   'you',
#   'you',
#   'we',
#   'we',
#   'you',
#   'path',
#   'we',
#   'you’re',
#   'you’re',
#   'you’re',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'is',
#   'is'],
#  'like': ['is', 'expecting'],
#  'freedom.': ['Liking', 'Live', 'Do'],
#  'Liking': ['what'],
#  'do': ['is', 'not', 'not', 'the', 'something', 'not', 'all'],
#  'happiness.': ['We'],
#  'We': ['forge',
#   'can',
#   'make',
#   'all',
#   'fear',
#   'ask',
#   'are',
#   'are',
#   'avoid',
#   'can',
#   'can'],
#  'forge': ['the'],
#  'chains': ['we'],
#  'wear': ['in'],
#  'life.': ['If', 'Focus', 'Being', 'It', 'You'],
#  'If': ['you', 'your', 'you', 'you', 'you', 'you', 'we', 'we'],
#  'look': ['to', 'so', 'at'],
#  'others': ['for', 'joy,', 'cannot', 'to', 'can'],
#  'fulfillment,': ['you'],
#  'never': ['be', 'be', 'decreases', 'regret', 'have', 'know'],
#  'fulfilled.': ['If'],
#  'happiness': ['depends',
#   'to',
#   'from',
#   'and',
#   'is',
#   'closes,',
#   'and',
#   'brings',
#   'with',
#   'really',
#   'Take',
#   'of',
#   'that',
#   'quote'],
#  'depends': ['on'],
#  'on': ['money,',
#   'our',
#   'the',
#   'life’s',
#   'the',
#   'your',
#   'them.',
#   'our',
#   'what',
#   'earth.',
#   'earth'],
#  'money,': ['you'],
#  'happy': ['with', 'with', 'life', 'would', 'is'],
#  'yourself.': ['Be', 'That'],
#  'Be': ['content', 'happy', 'excited'],
#  'content': ['with', 'means'],
#  'have;': ['rejoice'],
#  'rejoice': ['in'],
#  'way': ['things', 'is'],
#  'things': ['are.', 'as', 'I', 'I', 'we', 'that', 'that', 'you', 'I', 'I'],
#  'are.': ['When', 'I'],
#  'there': ['is', 'will', 'is.', 'will'],
#  'nothing': ['lacking,', 'can', 'to', 'enlightening', 'is.'],
#  'lacking,': ['the'],
#  'world': ['belongs', 'is', 'in'],
#  'belongs': ['to'],
#  'you.': ['Everything', 'For', 'Everything'],
#  'Everything': ['is', 'is', 'that', 'is', 'is'],
#  'gift': ['of', 'for', 'of'],
#  'universe': ['—even', '-'],
#  '—even': ['joy,'],
#  'joy,': ['anger,', 'and', 'anger,'],
#  'anger,': ['jealously,', 'jealously,'],
#  'jealously,': ['frustration,', 'frustration,'],
#  'frustration,': ['or', 'or'],
#  'or': ['separateness.',
#   'our',
#   'grief.',
#   'material',
#   'psychological',
#   'consumed.',
#   'unhappy',
#   'anticipate',
#   'loving.',
#   'even',
#   'it.',
#   'the',
#   'separateness.',
#   'our',
#   'smile,',
#   'discover.',
#   'the',
#   'at',
#   'tidy',
#   'last'],
#  'separateness.': ['Everything', 'Everything'],
#  'perfect': ['either', 'either'],
#  'either': ['for', 'for', 'for'],
#  'our': ['growth',
#   'enjoyment.',
#   'troubles',
#   'first',
#   'lives,',
#   'happiness',
#   'past,',
#   'experiences',
#   'growth',
#   'enjoyment.',
#   'deepest',
#   'light,',
#   'darkness,',
#   'light',
#   'own',
#   'presence',
#   'lives',
#   'car',
#   'lives,',
#   'conscious',
#   'lives',
#   'daily'],
#  'growth': ['or', 'or'],
#  'enjoyment.': ['There', 'We'],
#  'There': ['is', 'is', 'is', 'is', 'is'],
#  'such': ['thing'],
#  'thing': ['as', 'more'],
#  'problem': ['without', 'is'],
#  'without': ['a', 'remembering', 'forgetting.', 'a'],
#  'its': ['hands.', 'meaning', 'own'],
#  'hands.': ['You'],
#  'You': ['seek', 'cannot', 'never', 'are', 'are', 'can’t'],
#  'seek': ['problems', 'to', 'it.'],
#  'problems': ['because'],
#  'because': ['you', 'we', 'you', 'you'],
#  'need': ['their', 'for', 'for', 'to'],
#  'their': ['gifts.', 'exits', 'entrances;', 'value'],
#  'gifts.': ['If'],
#  'want': ['to', 'others', 'to'],
#  'happy,': ['set', 'practice', 'practice'],
#  'set': ['a'],
#  'goal': ['that'],
#  'commands': ['your'],
#  'liberates': ['your'],
#  'energy,': ['and'],
#  'inspires': ['your'],
#  'hopes.': ['Tension'],
#  'Tension': ['is'],
#  'who': ['you',
#   'you',
#   'are',
#   'can',
#   'we',
#   'can',
#   'lives',
#   'are',
#   'they',
#   'does'],
#  'think': ['you', 'the', '-', 'there'],
#  'should': ['be,', 'bring', 'bring'],
#  'be,': ['relaxation'],
#  'relaxation': ['is'],
#  'I': ['believe',
#   'cannot',
#   'can,',
#   'am',
#   'am',
#   'am',
#   'am',
#   'have.',
#   'cannot',
#   'can,'],
#  'believe': ['the'],
#  'recipe': ['for'],
#  'just': ['enough', 'expressed', 'in'],
#  'enough': ['money'],
#  'money': ['to'],
#  'pay': ['the'],
#  'monthly': ['bills'],
#  'bills': ['you'],
#  'acquire,': ['a'],
#  'little': ['surplus', 'too', 'temporary', 'charities'],
#  'surplus': ['to'],
#  'give': ['you', 'up', 'without', 'other'],
#  'confidence,': ['a'],
#  'too': ['much', 'much', 'precious,', 'short'],
#  'much': ['work', 'to'],
#  'work': ['each', 'again.', '-'],
#  'each': ['day,', 'of'],
#  'day,': ['enthusiasm'],
#  'enthusiasm': ['for'],
#  'work,': ['a', 'the'],
#  'substantial': ['share'],
#  'share': ['of', 'life’s', 'all', '-'],
#  'good': ['health,', 'person'],
#  'health,': ['a', 'family,'],
#  'couple': ['of'],
#  'real': ['friends', 'excitement'],
#  'friends': ['and'],
#  'wife': ['and'],
#  'children': ['to', 'do.'],
#  'life’s': ['beauty', 'big', 'smaller'],
#  'For': ['me'],
#  'me': ['it', 'the', 'serenity'],
#  'sufficient': ['to'],
#  'have': ['a',
#   'some.',
#   'their',
#   'peace',
#   'become',
#   'into',
#   'to',
#   'always',
#   'always',
#   'rather',
#   'sought',
#   'them.'],
#  'corner': ['by'],
#  'my': ['hearth,', 'god', 'devil.'],
#  'hearth,': ['a'],
#  'book': ['and'],
#  'friend,': ['and'],
#  'nap': ['undisturbed'],
#  'undisturbed': ['by'],
#  'creditors': ['or'],
#  'grief.': ['You'],
#  'cannot': ['judge', 'judge', 'be', 'be', 'change,', 'change,'],
#  'judge': ['what', 'what', 'your'],
#  'bring': ['others', 'you', 'happiness', 'us'],
#  'joy.': ['The'],
#  'The': ['art',
#   'best',
#   'secret',
#   'Pulitzer.',
#   'Nobel.',
#   'World',
#   'need',
#   'right',
#   'happiness',
#   'mind',
#   'moment'],
#  'art': ['of'],
#  'living': ['lies', 'every', 'by'],
#  'lies': ['less', 'our'],
#  'less': ['in'],
#  'eliminating': ['our'],
#  'troubles': ['than'],
#  'than': ['growing', 'learning', 'someone', 'of'],
#  'growing': ['with'],
#  'them.': ['Be', 'In', 'But', 'Happiness'],
#  'have.': ['Be', 'True', 'Gratitude'],
#  'excited': ['about'],
#  'about': ['what', 'the', 'others', 'shrinking', 'or', 'yesterday.', 'moving'],
#  'want.': ['Our', 'It', 'Happiness'],
#  'Our': ['capacity'],
#  'capacity': ['to'],
#  'draw': ['happiness'],
#  'aesthetic': ['objects'],
#  'objects': ['or'],
#  'material': ['goods'],
#  'goods': ['in'],
#  'fact': ['seems'],
#  'seems': ['critically'],
#  'critically': ['dependent'],
#  'dependent': ['on'],
#  'first': ['satisfying', 'place,', 'or'],
#  'satisfying': ['a'],
#  'more': ['important', 'of', 'painful'],
#  'important': ['range'],
#  'range': ['of'],
#  'emotional': ['or'],
#  'psychological': ['needs,'],
#  'needs,': ['among'],
#  'among': ['them'],
#  'them': ['the', 'if'],
#  'understanding,': ['for'],
#  'love,': ['expression', 'grace,', 'you'],
#  'expression': ['and'],
#  'respect.': ['If'],
#  'start': ['to'],
#  '‘out': ['there,’'],
#  'there,’': ['stop'],
#  'stop': ['yourself.'],
#  'That': ['thought', 'which'],
#  'thought': ['is'],
#  'problem.': ['Happiness'],
#  'Happiness': ['cannot',
#   'is',
#   'is',
#   'is',
#   'never',
#   'is',
#   'is',
#   'is',
#   'is',
#   'in',
#   'in',
#   'is'],
#  'traveled': ['to,'],
#  'to,': ['owned,'],
#  'owned,': ['earned,'],
#  'earned,': ['worn'],
#  'worn': ['or'],
#  'consumed.': ['Happiness'],
#  'spiritual': ['experience'],
#  'experience': ['of', 'change,', 'of', 'and', 'Heaven'],
#  'every': ['minute', 'sorrow,', 'man'],
#  'minute': ['with'],
#  'grace,': ['and'],
#  'gratitude.': ['Happiness'],
#  'not': ['a',
#   'the',
#   'in',
#   'be',
#   'change',
#   'to',
#   'attained',
#   'on',
#   'balanced',
#   'finishing',
#   'see',
#   'having',
#   'destroy',
#   'bound',
#   'bound',
#   'what',
#   'the',
#   'measured',
#   'our',
#   'to',
#   'just',
#   'learning',
#   'always',
#   'driven',
#   'seek',
#   'in',
#   'have',
#   'to',
#   'kill',
#   'happiness',
#   'to',
#   'be'],
#  'station': ['you'],
#  'arrive': ['at,'],
#  'at,': ['but'],
#  'manner': ['of'],
#  'traveling.': ['Happiness'],
#  'meaning': ['and', 'if', 'may', 'within'],
#  'purpose': ['of'],
#  'life,': ['the', 'fight'],
#  'whole': ['aim', 'movie.'],
#  'aim': ['and'],
#  'end': ['of', '-', 'of'],
#  'human': ['existence.'],
#  'existence.': ['Security'],
#  'Security': ['is'],
#  'when': ['everything', 'nothing', 'it'],
#  'everything': ['is', 'straight.', 'is', 'as'],
#  'settled,': ['when'],
#  'can': ['happen',
#   'be',
#   'be',
#   'give',
#   'give',
#   'have',
#   'lead',
#   'turn',
#   'look',
#   'gaze',
#   'smile',
#   'make'],
#  'happen': ['to'],
#  'you;': ['security'],
#  'security': ['is'],
#  'denial': ['of', 'into'],
#  'Focus': ['on'],
#  'journey,': ['not'],
#  'destination.': ['Joy'],
#  'Joy': ['is'],
#  'found': ['not'],
#  'finishing': ['an', 'what'],
#  'activity': ['but'],
#  'doing': ['it.', 'is', 'of', 'it,'],
#  'it.': ['Thousands',
#   'Life',
#   'Life',
#   'Life',
#   'Life',
#   'Life',
#   'Life',
#   'Life',
#   'Life',
#   'Life',
#   'Life',
#   'Life',
#   'Life',
#   'Life',
#   'Life',
#   'Life',
#   'Success',
#   'Love',
#   'God,',
#   'It’s',
#   'The',
#   'To'],
#  'Thousands': ['of'],
#  'candles': ['can'],
#  'lit': ['from'],
#  'single': ['candle,'],
#  'candle,': ['and'],
#  'life': ['of', 'cannot', 'by', 'is', 'is', 'to', 'that', 'is', 'to', 'as'],
#  'candle': ['will'],
#  'shortened.': ['Happiness'],
#  'decreases': ['by'],
#  'being': ['shared.', 'kind.', 'in', 'who', 'better'],
#  'shared.': ['The'],
#  'best': ['remedy', 'in', 'and'],
#  'remedy': ['for'],
#  'those': ['who', 'who'],
#  'are': ['afraid,',
#   'those',
#   'the',
#   'inadequate,',
#   'powerful',
#   'you',
#   'a',
#   'all',
#   'born',
#   'liberated',
#   'not',
#   'grateful',
#   'responsible',
#   'a',
#   'a'],
#  'afraid,': ['lonely'],
#  'lonely': ['or'],
#  'unhappy': ['is'],
#  'go': ['outside,', 'of'],
#  'outside,': ['somewhere'],
#  'somewhere': ['where'],
#  'where': ['they', 'we', 'we'],
#  'they': ['can',
#   'come',
#   'become',
#   'will',
#   'have',
#   'shall',
#   'become',
#   'do',
#   'are,'],
#  'quiet,': ['alone'],
#  'alone': ['with'],
#  'heavens,': ['nature'],
#  'nature': ['and', 'and'],
#  'God.': ['As', 'Your'],
#  'long': ['as', 'at'],
#  'this': ['exists,', 'is', 'world'],
#  'exists,': ['and'],
#  'certainly': ['always'],
#  'always': ['will,', 'the', 'done', 'got.', 'our'],
#  'will,': ['then'],
#  'then': ['there', 'acting', 'reflect'],
#  'comfort': ['for'],
#  'sorrow,': ['whatever', 'overcome'],
#  'whatever': ['the'],
#  'circumstances': ['may'],
#  'may': ['be.', 'not'],
#  'be.': ['In'],
#  'In': ['our', 'the', 'the', 'our'],
#  'lives,': ['change', 'as', 'we'],
#  'change': ['is', 'the', 'the', 'the', 'the'],
#  'unavoidable,': ['loss'],
#  'loss': ['is'],
#  'unavoidable.': ['In'],
#  'adaptability': ['and'],
#  'ease': ['with'],
#  'which': ['we', 'every', 'all', 'proceeds', 'secret', 'does'],
#  'change,': ['lies', 'the', 'courage'],
#  'Live': ['with', 'as'],
#  'intention.': ['Walk'],
#  'Walk': ['to'],
#  'edge.': ['Listen'],
#  'Listen': ['hard.'],
#  'hard.': ['Practice'],
#  'Practice': ['wellness.'],
#  'wellness.': ['Play'],
#  'Play': ['with'],
#  'abandon.': ['Laugh.'],
#  'Laugh.': ['Choose'],
#  'Choose': ['with'],
#  'regret.': ['Do'],
#  'Do': ['what', 'what'],
#  'love.': ['Live'],
#  'all': ['there', 'eligible', 'men', 'get', 'of', 'meant', 'that'],
#  'is.': ['You', 'In'],
#  'regret': ['being'],
#  'kind.': ['They'],
#  'They': ['who', 'have'],
#  'up': ['essential', 'to', 'of'],
#  'essential': ['liberty'],
#  'liberty': ['to', 'nor'],
#  'obtain': ['a'],
#  'temporary': ['safety,'],
#  'safety,': ['deserve'],
#  'deserve': ['neither'],
#  'neither': ['liberty', 'my'],
#  'nor': ['safety.', 'my'],
#  'safety.': ['Forgiveness'],
#  'Forgiveness': ['does'],
#  'does': ['not', 'enlarge', 'not', 'simply'],
#  'past,': ['but', 'worry', 'brings'],
#  'enlarge': ['the'],
#  'future.': ['The', 'We'],
#  'secret': ['of', 'of', 'garden'],
#  'health': ['for'],
#  'both': ['mind'],
#  'mind': ['and', 'is'],
#  'body': ['is'],
#  'mourn': ['for'],
#  'worry': ['about'],
#  'future,': ['or'],
#  'anticipate': ['troubles,'],
#  'troubles,': ['but'],
#  'present': ['moment', 'blessings,'],
#  'moment': ['wisely', 'one'],
#  'wisely': ['and'],
#  'earnestly.': ['True'],
#  'True': ['happiness', 'happiness...'],
#  'attained': ['through'],
#  'through': ['self-gratification,', 'fidelity'],
#  'self-gratification,': ['but'],
#  'fidelity': ['to'],
#  'worthy': ['purpose.'],
#  'purpose.': ['Most'],
#  'Most': ['of'],
#  'us': ['miss',
#   'more',
#   'about',
#   'to',
#   'until',
#   'pleasure—the',
#   'grateful,',
#   'happy.'],
#  'miss': ['out'],
#  'out': ['on'],
#  'big': ['prizes.'],
#  'prizes.': ['The'],
#  'Pulitzer.': ['The'],
#  'Nobel.': ['Oscars.'],
#  'Oscars.': ['The'],
#  'World': ['Cup.'],
#  'Cup.': ['But'],
#  'But': ['we’re', 'the'],
#  'we’re': ['all', 'afraid'],
#  'eligible': ['for'],
#  'smaller': ['prizes...'],
#  'prizes...': ['A'],
#  'A': ['pat',
#   'kiss',
#   'four-pound',
#   'full',
#   'crackling',
#   'great',
#   'glorious',
#   'smile',
#   'man'],
#  'pat': ['on'],
#  'back.': ['A'],
#  'kiss': ['behind', 'or'],
#  'behind': ['the'],
#  'ear.': ['A'],
#  'four-pound': ['bass.'],
#  'bass.': ['A'],
#  'full': ['moon.'],
#  'moon.': ['An'],
#  'An': ['empty'],
#  'empty': ['parking'],
#  'parking': ['space.'],
#  'space.': ['A'],
#  'crackling': ['fire.'],
#  'fire.': ['A'],
#  'great': ['meal.'],
#  'meal.': ['A'],
#  'glorious': ['sunset.'],
#  'sunset.': ['Hot'],
#  'Hot': ['soup.'],
#  'soup.': ['Cold'],
#  'Cold': ['beer.'],
#  'beer.': ['Money'],
#  'Money': ['is', 'doesn’t'],
#  'god': ['nor'],
#  'devil.': ['It'],
#  'It': ['is', 'is', 'comes', 'is', 'turns', 'turns', 'can', 'is', 'is', 'is'],
#  'form': ['of'],
#  'energy': ['that'],
#  'tends': ['to'],
#  'make': ['us', 'it.', 'a', 'a', 'trouble', 'peace', 'themselves', 'a'],
#  'already': ['are,'],
#  'are,': ['whether', 'not'],
#  'whether': ['it’s'],
#  'it’s': ['greedy', 'not', 'really'],
#  'greedy': ['or'],
#  'loving.': ['The'],
#  'forgiveness': ['is'],
#  'illusion.': ['There'],
#  'forgive.': ['Blessed'],
#  'Blessed': ['are'],
#  'remembering': ['and'],
#  'take': ['without', 'things', 'next...', 'to', 'your'],
#  'forgetting.': ['Reflect'],
#  'Reflect': ['upon'],
#  'upon': ['you'],
#  'blessings,': ['of'],
#  'has': ['many', 'been', 'meaning'],
#  'many': ['-', 'parts.', 'different'],
#  'past': ['misfortunes,', 'and'],
#  'misfortunes,': ['of'],
#  'men': ['have', 'and'],
#  'some.': ['Even'],
#  'Even': ['a'],
#  'measure': ['of'],
#  'darkness,': ['and', 'that'],
#  'word': ['happy'],
#  'would': ['lose', 'have'],
#  'lose': ['its'],
#  'were': ['not', 'seeing'],
#  'balanced': ['by'],
#  'sadness.': ['It'],
#  'far': ['better'],
#  'better': ['to', 'than'],
#  'come': ['along', 'from', 'from'],
#  'along': ['with'],
#  'patience': ['and'],
#  'equanimity.': ['Much'],
#  'Much': ['of'],
#  'stress': ['that', 'in'],
#  'people': ['feel', 'that', 'thinking', 'around', 'permission'],
#  'feel': ['doesn’t', 'insecure.'],
#  'doesn’t': ['come', 'bring', 'serve'],
#  'having': ['too', 'what'],
#  'do.': ['It', 'We'],
#  'they’ve': ['started.'],
#  'started.': ['He'],
#  'He': ['who'],
#  'lives': ['in', 'in', 'come', 'but'],
#  'harmony': ['with', 'with'],
#  'himself': ['lives'],
#  'universe.': ['If'],
#  'practice': ['compassion.', 'compassion.'],
#  'compassion.': ['If', 'All'],
#  'All': ['the', 'this'],
#  'world’s': ['a'],
#  'stage,': ['and'],
#  'women': ['merely'],
#  'merely': ['players.'],
#  'players.': ['They'],
#  'exits': ['and'],
#  'entrances;': ['and'],
#  'his': ['time'],
#  'time': ['plays', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'on'],
#  'plays': ['many'],
#  'parts.': ['Dream'],
#  'Dream': ['as'],
#  'you’ll': ['live', 'die', 'get'],
#  'forever,': ['live'],
#  'die': ['today.'],
#  'today.': ['When'],
#  'door': ['of', 'that'],
#  'closes,': ['another'],
#  'another': ['opens,'],
#  'opens,': ['but'],
#  'often': ['we'],
#  'so': ['long', 'that'],
#  'at': ['the', 'someone', 'a', 'a', 'a', 'a', 'everything'],
#  'closed': ['door'],
#  'see': ['the', 'that'],
#  'been': ['opened'],
#  'opened': ['for'],
#  'us.': ['Happiness', 'We', 'It'],
#  'appreciating': ['what'],
#  'happiness...': ['arises,'],
#  'arises,': ['in'],
#  'place,': ['from', 'and'],
#  'enjoyment': ['of'],
#  'one’s': ['self.', 'values.'],
#  'self.': ['Happiness'],
#  'state': ['of'],
#  'consciousness': ['which'],
#  'proceeds': ['from'],
#  'achievement': ['of'],
#  'values.': ['All'],
#  'play...': ['be'],
#  'thou': ['the'],
#  'joyful': ['player.'],
#  'player.': ['Life'],
#  'opportunity,': ['benefit'],
#  'benefit': ['from'],
#  'beauty,': ['admire'],
#  'admire': ['it.'],
#  'bliss,': ['taste'],
#  'taste': ['it.'],
#  'dream,': ['realize'],
#  'challenge,': ['meet'],
#  'meet': ['it.'],
#  'duty,': ['complete'],
#  'complete': ['it.'],
#  'game,': ['play'],
#  'play': ['it.', '-'],
#  'promise,': ['fulfill'],
#  'fulfill': ['it.'],
#  'overcome': ['it.'],
#  'song,': ['sing'],
#  'sing': ['it.'],
#  'struggle,': ['accept'],
#  'accept': ['it.', 'the', 'will', 'the'],
#  'tragedy,': ['confront'],
#  'confront': ['it.', 'them.'],
#  'adventure,': ['dare'],
#  'dare': ['it.'],
#  'luck,': ['make'],
#  'precious,': ['do'],
#  'destroy': ['it.'],
#  'fight': ['for'],
#  'Success': ['is'],
#  'getting': ['what'],
#  'wanting': ['what', 'to', 'to'],
#  'get.': ['We'],
#  'peace': ['if', 'for', 'with'],
#  'let': ['go', 'our'],
#  'control': ['the'],
#  'get,': ['we'],
#  'give.': ['Money'],
#  'creativity.': ['Your'],
#  'Your': ['creativity', 'playing'],
#  'creativity': ['and'],
#  'brings': ['money.', 'peace'],
#  'money.': ['Happiness'],
#  'loving': ['life.', 'what'],
#  'Being': ['happy'],
#  'momentary': ['experience.'],
#  'experience.': ['And', 'Once'],
#  'And': ['love', 'as'],
#  'looking': ['at'],
#  'someone': ['or', 'else.', 'we'],
#  'even': ['something', 'joy,', 'a'],
#  'something': ['and', 'you'],
#  'seeing': ['the', 'it'],
#  'absolute': ['best'],
#  'him/her': ['or'],
#  'Love': ['is'],
#  'see.': ['So'],
#  'So': ['love'],
#  'really': ['are', 'in', 'about'],
#  'same': ['thing...'],
#  'thing...': ['just'],
#  'expressed': ['differently.'],
#  'differently.': ['Everything'],
#  'irritates': ['us'],
#  'lead': ['us'],
#  'understanding': ['of'],
#  'ourselves.': ['God'],
#  'God': ['comforts', 'that'],
#  'comforts': ['the'],
#  'disturbed': ['and'],
#  'disturbs': ['the'],
#  'comfortable.': ['Carefully'],
#  'Carefully': ['watch'],
#  'watch': ['your', 'your', 'your'],
#  'THOUGHTS,': ['for'],
#  'become': ['your', 'your', 'your', 'your', 'YOUR', 'uncomfortable'],
#  'WORDS.': ['Manage'],
#  'Manage': ['and'],
#  'WORDS,': ['for'],
#  'ACTIONS.': ['Consider'],
#  'Consider': ['and'],
#  'ACTIONS,': ['for'],
#  'HABITS.': ['Acknowledge'],
#  'Acknowledge': ['and'],
#  'HABITS,': ['for'],
#  'shall': ['become'],
#  'VALUES.': ['Understand'],
#  'Understand': ['and'],
#  'embrace': ['your'],
#  'VALUES,': ['for'],
#  'YOUR': ['DESTINY.'],
#  'DESTINY.': ['Wisdom'],
#  'Wisdom': ['is'],
#  'knowing': ['what'],
#  'path': ['to'],
#  'next...': ['Integrity'],
#  'Integrity': ['is'],
#  'God,': ['grant', 'grant'],
#  'grant': ['me', 'me'],
#  'serenity': ['to', 'to'],
#  'courage': ['to', 'to'],
#  'can,': ['and', 'and'],
#  'wisdom': ['to', 'Take', 'to'],
#  'know': ['the', 'or', 'the', 'peace;'],
#  'difference.': ['I', 'That'],
#  'am': ['not', 'bound', 'not', 'bound'],
#  'bound': ['to', 'to', 'to', 'to'],
#  'win,': ['I'],
#  'true.': ['I'],
#  'succeed,': ['but'],
#  'light': ['I', 'shine,'],
#  'Gratitude': ['unlocks', 'makes'],
#  'unlocks': ['the'],
#  'fullness': ['of'],
#  'turns': ['what', 'denial'],
#  'into': ['enough,', 'acceptance,', 'a', 'a', 'a'],
#  'enough,': ['and'],
#  'more.': ['It'],
#  'acceptance,': ['chaos'],
#  'chaos': ['to'],
#  'order,': ['confusion'],
#  'confusion': ['to'],
#  'clarity.': ['It'],
#  'turn': ['a'],
#  'meal': ['into'],
#  'feast,': ['a'],
#  'house': ['into'],
#  'home,': ['a'],
#  'stranger': ['into'],
#  'friend.': ['Gratitude'],
#  'makes': ['sense', 'you', 'us', 'us'],
#  'sense': ['of'],
#  'today,': ['and'],
#  'vision': ['for'],
#  'tomorrow.': ['We'],
#  'get': ['report', 'in', 'there.', 'what'],
#  'report': ['cards'],
#  'cards': ['in'],
#  'different': ['ways,'],
#  'ways,': ['but'],
#  'excitement': ['of'],
#  'you’re': ['doing', 'gonna', 'doing.'],
#  'It’s': ['not'],
#  'gonna': ['get'],
#  'final': ['curtain'],
#  'curtain': ['-'],
#  'it,': ['and', 'but'],
#  'doing.': ['Happiness'],
#  'measured': ['by', 'by', 'by'],
#  'achieve,': ['the'],
#  'places': ['we'],
#  'go,': ['or'],
#  'route': ['that'],
#  'there.': ['Happiness'],
#  'experiences': ['with.'],
#  'with.': ['There'],
#  'world,': ['only'],
#  'only': ['people', 'one'],
#  'thinking': ['stressful'],
#  'stressful': ['thoughts'],
#  'thoughts': ['and'],
#  'acting': ['on'],
#  'midst': ['of'],
#  'movement': ['and'],
#  'chaos,': ['keep'],
#  'keep': ['stillness', 'blaming'],
#  'stillness': ['inside'],
#  'inside': ['of'],
#  'fear': ['that', 'is'],
#  'inadequate,': ['but'],
#  'deepest': ['fear'],
#  'powerful': ['beyond'],
#  'beyond': ['measure.'],
#  'measure.': ['It'],
#  'light,': ['not'],
#  'most': ['frightens'],
#  'frightens': ['us.'],
#  'ask': ['ourselves:'],
#  'ourselves:': ['Actually,'],
#  'Actually,': ['who'],
#  'these': ['things?'],
#  'things?': ['You'],
#  'playing': ['small'],
#  'small': ['doesn’t'],
#  'serve': ['the'],
#  'world.': ['There'],
#  'enlightening': ['about'],
#  'shrinking': ['so'],
#  'other': ['people', 'people'],
#  'around': ['you'],
#  'won’t': ['feel'],
#  'insecure.': ['We'],
#  'meant': ['to'],
#  'shine': ['as'],
#  'born': ['to'],
#  'manifest': ['the'],
#  'glory': ['of'],
#  'within': ['us.', 'the'],
#  'some': ['of'],
#  'us;': ['it'],
#  'everyone.': ['And'],
#  'shine,': ['we'],
#  'unconsciously': ['give'],
#  'permission': ['to'],
#  'same.': ['As'],
#  'liberated': ['from'],
#  'own': ['fear,', 'place,'],
#  'fear,': ['our'],
#  'presence': ['automatically'],
#  'automatically': ['releases'],
#  'releases': ['others.'],
#  'others.': ['A'],
#  'smile': ['is', 'at'],
#  'curve': ['that'],
#  'sets': ['everything'],
#  'straight.': ['There'],
#  'painful': ['than'],
#  'learning': ['from', 'from'],
#  'Once': ['you'],
#  'again.': ['Take'],
#  'Take': ['time',
#   'time',
#   'time',
#   'time',
#   'time',
#   'time',
#   'time',
#   'time',
#   'time'],
#  'price': ['of'],
#  'success': ['Take'],
#  'source': ['of'],
#  'power': ['Take'],
#  'perpetual': ['youth'],
#  'youth': ['Take'],
#  'read': ['-'],
#  'fountain': ['of'],
#  'friendly': ['-'],
#  'road': ['to'],
#  'loved': ['-'],
#  'nourishment': ['of'],
#  'soul': ['Take'],
#  'short': ['a'],
#  'selfish': ['Take'],
#  'laugh': ['-'],
#  'music': ['of'],
#  'heart': ['Take'],
#  'dream': ['-'],
#  'hitching': ['your'],
#  'wagon': ['to'],
#  'star.': ['Anything'],
#  'Anything': ['in'],
#  'don’t': ['accept'],
#  'simply': ['make', 'what'],
#  'trouble': ['for'],
#  'until': ['we', 'the'],
#  'right': ['way', 'when'],
#  'popular': ['and'],
#  'easy': ['way.'],
#  'way.': ['Standing'],
#  'Standing': ['for'],
#  'unpopular': ['is'],
#  'true': ['test'],
#  'test': ['of'],
#  'moral': ['character.'],
#  'character.': ['Persons'],
#  'Persons': ['of'],
#  'high': ['self-esteem'],
#  'self-esteem': ['are'],
#  'driven': ['to'],
#  'themselves': ['superior', 'against'],
#  'superior': ['to'],
#  'others;': ['they'],
#  'prove': ['their'],
#  'value': ['by'],
#  'measuring': ['themselves'],
#  'against': ['a'],
#  'comparative': ['standard.'],
#  'standard.': ['Their'],
#  'Their': ['joy'],
#  'joy': ['is'],
#  'else.': ['Anxiety'],
#  'Anxiety': ['is'],
#  'dizziness': ['of'],
#  'done': ['and'],
#  'got.': ['The'],
#  'made': ['up'],
#  'charities': ['of'],
#  'smile,': ['a'],
#  'kind': ['look,'],
#  'look,': ['a'],
#  'heartfelt': ['compliment.'],
#  'compliment.': ['We'],
#  'avoid': ['the'],
#  'afraid': ['of'],
#  'dire': ['consequences', 'consequences'],
#  'consequences': ['if', 'in'],
#  'truly': ['dire'],
#  'avoiding': ['things'],
#  'learn': ['about'],
#  'discover.': ['If'],
#  'uncomfortable': ['in'],
#  'any': ['given'],
#  'given': ['moment,'],
#  'moment,': ['we'],
#  'flower,': ['a'],
#  'pebble': ['in'],
#  'street': ['or'],
#  'tire': ['on'],
#  'car': ['and'],
#  'grateful.': ['We'],
#  'gaze': ['at'],
#  'person': ['in', 'is'],
#  'distance': ['or'],
#  'cloud': ['in'],
#  'sky': ['and'],
#  'appreciative.': ['We'],
#  'stranger,': ['hug'],
#  'hug': ['someone'],
#  'tidy': ['a'],
#  'disorganized': ['shelf'],
#  'shelf': ['and'],
#  'thankful': ['for'],
#  'opportunity.': ['If'],
#  'choose': ['gratitude,', 'not'],
#  'gratitude,': ['we'],
#  'happy!': ['Life'],
#  'isn’t': ['measured'],
#  'breaths': ['you'],
#  'take,': ['but'],
#  'moments': ['that'],
#  'breath': ['away.'],
#  'away.': ['Think'],
#  'Think': ['of'],
#  'rather': ['than'],
#  'lack.': ['Of'],
#  'Of': ['the'],
#  'have,': ['select'],
#  'select': ['the'],
#  'reflect': ['how'],
#  'how': ['eagerly'],
#  'eagerly': ['you'],
#  'sought': ['them'],
#  'did': ['not'],
#  'very': ['rarely', 'end'],
#  'rarely': ['where'],
#  'To': ['be'],
#  'means': ['that'],
#  'contain': ['what'],
#  'seek.': ['Today'],
#  'Today': ['is'],
#  'tomorrow': ['you'],
#  'worried': ['about'],
#  'yesterday.': ['Was'],
#  'Was': ['it'],
#  'worth': ['it?'],
#  'it?': ['The'],
#  'itself': ['can'],
#  'heaven': ['of'],
#  'hell,': ['a'],
#  'hell': ['of'],
#  'heaven.': ['Both'],
#  'Both': ['abundance'],
#  'abundance': ['and', 'that’s'],
#  'lack': ['exist'],
#  'exist': ['simultaneously'],
#  'simultaneously': ['in'],
#  'parallel': ['realities.'],
#  'realities.': ['It'],
#  'conscious': ['choice'],
#  'choice': ['which'],
#  'garden': ['we'],
#  'tend...when': ['we'],
#  'focus': ['on'],
#  'missing': ['from'],
#  'grateful': ['for'],
#  'that’s': ['present—love,'],
#  'present—love,': ['health,'],
#  'family,': ['friends,'],
#  'friends,': ['work,'],
#  'joys': ['of'],
#  'personal': ['pursuits'],
#  'pursuits': ['that'],
#  'pleasure—the': ['wasteland'],
#  'wasteland': ['of'],
#  'illusion': ['falls'],
#  'falls': ['away'],
#  'away': ['and'],
#  'Heaven': ['on'],
#  'earth.': ['The'],
#  'gives': ['close'],
#  'close': ['attention'],
#  'attention': ['to'],
#  'anything,': ['even'],
#  'blade': ['of'],
#  'grass,': ['it'],
#  'becomes': ['a'],
#  'mysterious,': ['awesome,'],
#  'awesome,': ['indescribably'],
#  'indescribably': ['magnificent'],
#  'magnificent': ['world'],
#  'itself.': ['God,'],
#  'kill': ['you'],
#  'stronger.': ['Boredom'],
#  'Boredom': ['is'],
#  'feeling': ['that'],
#  'waste': ['of'],
#  'time;': ['serenity,'],
#  'serenity,': ['that'],
#  'daily': ['lives,'],
#  'must': ['see', 'do'],
#  'grateful,': ['but'],
#  'gratefulness': ['that'],
#  'happy.': ['A'],
#  'required': ['of'],
#  'him': ['will'],
#  'peace;': ['for'],
#  'that,': ['he'],
#  'he': ['must', 'can.'],
#  'can.': ['Look'],
#  'Look': ['at'],
#  'though': ['you'],
#  'last': ['time.'],
#  'time.': ['Then'],
#  'Then': ['your'],
#  'earth': ['will'],
#  'filled': ['with'],
#  'glory.': ['You'],
#  'responsible': ['for'],
#  'can’t': ['keep'],
#  'blaming': ['somebody'],
#  'somebody': ['else'],
#  'dysfunction.': ['Life'],
#  'moving': ['on.'],
#  'on.': ['Expecting'],
#  'Expecting': ['life'],
#  'treat': ['you'],
#  'well': ['because'],
#  'expecting': ['an'],
#  'angry': ['bull'],
#  'bull': ['not'],
#  'charge': ['because'],
#  'vegetarian.': ['View'],
#  'View': ['life'],
#  'series': ['of'],
#  'movie': ['frames,'],
#  'frames,': ['the'],
#  'ending': ['and'],
#  'apparent': ['until'],
#  'movie,': ['and'],
#  'yet,': ['each'],
#  'hundreds': ['of'],
#  'individual': ['frames'],
#  'frames': ['has'],
#  'context': ['of'],
#  'movie.': ['—Victor'],
#  '—Victor': ['Frankl'],
#  'Frankl': ['happiness'],
#  'quote': ['—Tishan'],
#  '—Tishan': ['—Theodore'],
#  '—Theodore': ['Roosevelt']}

# %% [markdown]
# ## Exercise 2: Create a text generator
#
# Update the `generate()` method to generate sentences using the Markov property.
#
# - This should use the `.term_dict`, and it should take in the number of terms you want generated, `term_count`.
# - Your function should also be able to accept an *optional* user-defined `seed_term` that starts the generator. By default, you can have the function select a random first token.
#   - If the user-defined seed term is not in the corpus, raise a `ValueError`.
# - Each "next word" should be chosen *at random* given the "current" word and the term dictionary.
#   - Consider [`numpy.random.choice`](https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html) for this.
#
# *Hint: think about what happens if the last term in the corpus occurs only **once**.*

# %%
text_gen.generate()
# Out:
# 'confidence, a pebble in life is beauty, admire it. Life is unpopular is measured by'

# %% [markdown]
# *Note: this exercise illustrates both a Markov Chain (with constant transition probabilities) **and** a [Monte Carlo Simulation](https://en.wikipedia.org/wiki/Monte_Carlo_method) (iterative sampling from a constantly defined probability distribution of words)!*

# %% [markdown]
# ---
#
# # Bonus Exercise
#
# *<font color='darkorange'>The following exercise is completely optional</font>, and will not be reviewed unless explicitly requested. That said, these are interesting to work on if you have the time!*

# %% [markdown]
# Adjust your text generator such that we can increase the "state window size" from one word to `k` words. That is, the term dictionary in this version with `k = 2` would look something like this (*note the tuple keys*):
#
# ```python
# {
#     ("Healing", "comes"): ["from", ...],
#     ...,
#     ("it", "is"): ["you", "very"],
#     ...
# }
# ```
#
# Generate some text for `k` values of 1, 2, and 3, and compare the differences in text coherence. Try larger corpuses ...

# %%
text_gen = MarkovText(corpus, k=2)

text_gen.get_term_dict()
# Out:
# {('Healing', 'comes'): ['from'],
#  ('comes', 'from'): ['taking', 'not'],
#  ('from', 'taking'): ['responsibility:'],
#  ('taking', 'responsibility:'): ['to'],
#  ('responsibility:', 'to'): ['realize'],
#  ('to', 'realize'): ['that'],
#  ('realize', 'that'): ['it'],
#  ('that', 'it'): ['is', 'is'],
#  ('it', 'is'): ['you',
#   'sufficient',
#   'in',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'too',
#   'the',
#   'hitching',
#   'unpopular',
#   'not'],
#  ('is', 'you'): ['-'],
#  ('you', '-'): ['and'],
#  ('-', 'and'): ['no'],
#  ('and', 'no'): ['one'],
#  ('no', 'one'): ['else'],
#  ('one', 'else'): ['-'],
#  ('else', '-'): ['that'],
#  ('-', 'that'): ['creates'],
#  ('that', 'creates'): ['your'],
#  ('creates', 'your'): ['thoughts,'],
#  ('your', 'thoughts,'): ['your', 'liberates'],
#  ('thoughts,', 'your'): ['feelings,'],
#  ('your', 'feelings,'): ['and'],
#  ('feelings,', 'and'): ['your'],
#  ('and', 'your'): ['actions.'],
#  ('your', 'actions.'): ['Life'],
#  ('actions.', 'Life'): ['is'],
#  ('Life', 'is'): ['a',
#   'an',
#   'beauty,',
#   'bliss,',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'sorrow,',
#   'a',
#   'a',
#   'a',
#   'an',
#   'luck,',
#   'too',
#   'life,',
#   'really'],
#  ('is', 'a'): ['journey',
#   'gift',
#   'form',
#   'dream,',
#   'challenge,',
#   'duty,',
#   'game,',
#   'promise,',
#   'song,',
#   'struggle,',
#   'tragedy,',
#   'gift',
#   'curve',
#   'true',
#   'waste'],
#  ('a', 'journey'): ['and', 'by'],
#  ('journey', 'and'): ['if'],
#  ('and', 'if'): ['you'],
#  ('if', 'you'): ['fall', 'did'],
#  ('you', 'fall'): ['in'],
#  ('fall', 'in'): ['love'],
#  ('in', 'love'): ['with', 'forever.', 'with'],
#  ('love', 'with'): ['the', 'that'],
#  ('with', 'the'): ['journey', 'heavens,', 'universe.'],
#  ('the', 'journey'): ['you'],
#  ('journey', 'you'): ['will'],
#  ('you', 'will'): ['be', 'never', 'never'],
#  ('will', 'be'): ['in', 'comfort', 'dire', 'happy!', 'filled'],
#  ('be', 'in'): ['love'],
#  ('love', 'forever.'): ['When'],
#  ('forever.', 'When'): ['you'],
#  ('When', 'you'): ['return', 'realize'],
#  ('you', 'return'): ['to'],
#  ('return', 'to'): ['your'],
#  ('to', 'your'): ['old'],
#  ('your', 'old'): ['hometown,'],
#  ('old', 'hometown,'): ['you'],
#  ('hometown,', 'you'): ['find'],
#  ('you', 'find'): ['it'],
#  ('find', 'it'): ['wasn’t'],
#  ('it', 'wasn’t'): ['the'],
#  ('wasn’t', 'the'): ['town'],
#  ('the', 'town'): ['you'],
#  ('town', 'you'): ['missed,'],
#  ('you', 'missed,'): ['but'],
#  ('missed,', 'but'): ['your'],
#  ('but', 'your'): ['childhood.'],
#  ('your', 'childhood.'): ['As'],
#  ('childhood.', 'As'): ['we'],
#  ('As', 'we'): ['grow', 'are'],
#  ('we', 'grow'): ['old,'],
#  ('grow', 'old,'): ['the'],
#  ('old,', 'the'): ['beauty'],
#  ('the', 'beauty'): ['steals'],
#  ('beauty', 'steals'): ['inward.'],
#  ('steals', 'inward.'): ['Life'],
#  ('inward.', 'Life'): ['begins'],
#  ('Life', 'begins'): ['as'],
#  ('begins', 'as'): ['a'],
#  ('as', 'a'): ['quest', 'journey', 'problem', 'series'],
#  ('a', 'quest'): ['of'],
#  ('quest', 'of'): ['the'],
#  ('of', 'the'): ['child',
#   'universe',
#   'candle',
#   'stress',
#   'universe',
#   'soul',
#   'heart',
#   'little',
#   'movie,',
#   'hundreds',
#   'whole'],
#  ('the', 'child'): ['for'],
#  ('child', 'for'): ['the'],
#  ('for', 'the'): ['man,', 'past,', 'opportunity.', 'abundance', 'first'],
#  ('the', 'man,'): ['and'],
#  ('man,', 'and'): ['ends'],
#  ('and', 'ends'): ['as'],
#  ('ends', 'as'): ['a'],
#  ('journey', 'by'): ['the'],
#  ('by', 'the'): ['man', 'things', 'people', 'breaths', 'moments'],
#  ('the', 'man'): ['to'],
#  ('man', 'to'): ['rediscover'],
#  ('to', 'rediscover'): ['the'],
#  ('rediscover', 'the'): ['child.'],
#  ('the', 'child.'): ['Ultimately'],
#  ('child.', 'Ultimately'): ['your'],
#  ('Ultimately', 'your'): ['greatest'],
#  ('your', 'greatest'): ['teacher'],
#  ('greatest', 'teacher'): ['is'],
#  ('teacher', 'is'): ['to'],
#  ('is', 'to'): ['live', 'go'],
#  ('to', 'live'): ['with', 'in', 'up'],
#  ('live', 'with'): ['an'],
#  ('with', 'an'): ['open'],
#  ('an', 'open'): ['heart.'],
#  ('open', 'heart.'): ['Doing'],
#  ('heart.', 'Doing'): ['what'],
#  ('Doing', 'what'): ['you'],
#  ('what', 'you'): ['like',
#   'do',
#   'have;',
#   'have.',
#   'want.',
#   'love.',
#   'want.',
#   'have.',
#   'want.',
#   'get.',
#   'see.',
#   'have',
#   'have',
#   'have',
#   'lack.',
#   'seek.'],
#  ('you', 'like'): ['is'],
#  ('like', 'is'): ['freedom.'],
#  ('is', 'freedom.'): ['Liking'],
#  ('freedom.', 'Liking'): ['what'],
#  ('Liking', 'what'): ['you'],
#  ('you', 'do'): ['is', 'something'],
#  ('do', 'is'): ['happiness.'],
#  ('is', 'happiness.'): ['We'],
#  ('happiness.', 'We'): ['forge'],
#  ('We', 'forge'): ['the'],
#  ('forge', 'the'): ['chains'],
#  ('the', 'chains'): ['we'],
#  ('chains', 'we'): ['wear'],
#  ('we', 'wear'): ['in'],
#  ('wear', 'in'): ['life.'],
#  ('in', 'life.'): ['If'],
#  ('life.', 'If'): ['you'],
#  ('If', 'you'): ['look', 'want', 'start', 'want', 'want'],
#  ('you', 'look'): ['to'],
#  ('look', 'to'): ['others'],
#  ('to', 'others'): ['for'],
#  ('others', 'for'): ['fulfillment,'],
#  ('for', 'fulfillment,'): ['you'],
#  ('fulfillment,', 'you'): ['will'],
#  ('will', 'never'): ['be', 'be', 'know'],
#  ('never', 'be'): ['fulfilled.', 'happy'],
#  ('be', 'fulfilled.'): ['If'],
#  ('fulfilled.', 'If'): ['your'],
#  ('If', 'your'): ['happiness'],
#  ('your', 'happiness'): ['depends'],
#  ('happiness', 'depends'): ['on'],
#  ('depends', 'on'): ['money,'],
#  ('on', 'money,'): ['you'],
#  ('money,', 'you'): ['will'],
#  ('be', 'happy'): ['with'],
#  ('happy', 'with'): ['yourself.', 'what'],
#  ('with', 'yourself.'): ['Be'],
#  ('yourself.', 'Be'): ['content'],
#  ('Be', 'content'): ['with'],
#  ('content', 'with'): ['what'],
#  ('with', 'what'): ['you', 'you', 'you'],
#  ('you', 'have;'): ['rejoice'],
#  ('have;', 'rejoice'): ['in'],
#  ('rejoice', 'in'): ['the'],
#  ('in', 'the'): ['way',
#   'present',
#   'first',
#   'doing',
#   'end',
#   'doing',
#   'world,',
#   'street',
#   'distance',
#   'sky'],
#  ('the', 'way'): ['things'],
#  ('way', 'things'): ['are.'],
#  ('things', 'are.'): ['When'],
#  ('are.', 'When'): ['you'],
#  ('you', 'realize'): ['there', 'you'],
#  ('realize', 'there'): ['is'],
#  ('there', 'is'): ['nothing'],
#  ('is', 'nothing'): ['lacking,', 'to', 'enlightening'],
#  ('nothing', 'lacking,'): ['the'],
#  ('lacking,', 'the'): ['world'],
#  ('the', 'world'): ['belongs'],
#  ('world', 'belongs'): ['to'],
#  ('belongs', 'to'): ['you.'],
#  ('to', 'you.'): ['Everything'],
#  ('you.', 'Everything'): ['is', 'is'],
#  ('Everything', 'is'): ['a', 'perfect', 'a', 'perfect'],
#  ('a', 'gift'): ['of', 'for', 'of'],
#  ('gift', 'of'): ['the', 'the'],
#  ('the', 'universe'): ['—even', '-'],
#  ('universe', '—even'): ['joy,'],
#  ('—even', 'joy,'): ['anger,'],
#  ('joy,', 'anger,'): ['jealously,', 'jealously,'],
#  ('anger,', 'jealously,'): ['frustration,', 'frustration,'],
#  ('jealously,', 'frustration,'): ['or', 'or'],
#  ('frustration,', 'or'): ['separateness.', 'separateness.'],
#  ('or', 'separateness.'): ['Everything', 'Everything'],
#  ('separateness.', 'Everything'): ['is', 'is'],
#  ('is', 'perfect'): ['either', 'either'],
#  ('perfect', 'either'): ['for', 'for'],
#  ('either', 'for'): ['our', 'our', 'the'],
#  ('for', 'our'): ['growth', 'growth'],
#  ('our', 'growth'): ['or', 'or'],
#  ('growth', 'or'): ['our', 'our'],
#  ('or', 'our'): ['enjoyment.', 'enjoyment.'],
#  ('our', 'enjoyment.'): ['There', 'We'],
#  ('enjoyment.', 'There'): ['is'],
#  ('There', 'is'): ['no', 'nothing', 'no', 'nothing', 'only'],
#  ('is', 'no'): ['such', 'stress'],
#  ('no', 'such'): ['thing'],
#  ('such', 'thing'): ['as'],
#  ('thing', 'as'): ['a'],
#  ('a', 'problem'): ['without'],
#  ('problem', 'without'): ['a'],
#  ('without', 'a'): ['gift', 'measure'],
#  ('gift', 'for'): ['you'],
#  ('for', 'you'): ['in'],
#  ('you', 'in'): ['its'],
#  ('in', 'its'): ['hands.'],
#  ('its', 'hands.'): ['You'],
#  ('hands.', 'You'): ['seek'],
#  ('You', 'seek'): ['problems'],
#  ('seek', 'problems'): ['because'],
#  ('problems', 'because'): ['you'],
#  ('because', 'you'): ['need', 'are', 'are'],
#  ('you', 'need'): ['their'],
#  ('need', 'their'): ['gifts.'],
#  ('their', 'gifts.'): ['If'],
#  ('gifts.', 'If'): ['you'],
#  ('you', 'want'): ['to', 'others', 'to'],
#  ('want', 'to'): ['be', 'be'],
#  ('to', 'be'): ['happy,',
#   'just',
#   'happy,',
#   'happy,',
#   'true.',
#   'these',
#   'friendly',
#   'selfish'],
#  ('be', 'happy,'): ['set', 'practice', 'practice'],
#  ('happy,', 'set'): ['a'],
#  ('set', 'a'): ['goal'],
#  ('a', 'goal'): ['that'],
#  ('goal', 'that'): ['commands'],
#  ('that', 'commands'): ['your'],
#  ('commands', 'your'): ['thoughts,'],
#  ('thoughts,', 'liberates'): ['your'],
#  ('liberates', 'your'): ['energy,'],
#  ('your', 'energy,'): ['and'],
#  ('energy,', 'and'): ['inspires'],
#  ('and', 'inspires'): ['your'],
#  ('inspires', 'your'): ['hopes.'],
#  ('your', 'hopes.'): ['Tension'],
#  ('hopes.', 'Tension'): ['is'],
#  ('Tension', 'is'): ['who'],
#  ('is', 'who'): ['you', 'you'],
#  ('who', 'you'): ['think', 'are.'],
#  ('you', 'think'): ['you'],
#  ('think', 'you'): ['should'],
#  ('you', 'should'): ['be,'],
#  ('should', 'be,'): ['relaxation'],
#  ('be,', 'relaxation'): ['is'],
#  ('relaxation', 'is'): ['who'],
#  ('you', 'are.'): ['I'],
#  ('are.', 'I'): ['believe'],
#  ('I', 'believe'): ['the'],
#  ('believe', 'the'): ['recipe'],
#  ('the', 'recipe'): ['for'],
#  ('recipe', 'for'): ['happiness'],
#  ('for', 'happiness'): ['to'],
#  ('happiness', 'to'): ['be'],
#  ('be', 'just'): ['enough'],
#  ('just', 'enough'): ['money'],
#  ('enough', 'money'): ['to'],
#  ('money', 'to'): ['pay'],
#  ('to', 'pay'): ['the'],
#  ('pay', 'the'): ['monthly'],
#  ('the', 'monthly'): ['bills'],
#  ('monthly', 'bills'): ['you'],
#  ('bills', 'you'): ['acquire,'],
#  ('you', 'acquire,'): ['a'],
#  ('acquire,', 'a'): ['little'],
#  ('a', 'little'): ['surplus', 'too', 'temporary'],
#  ('little', 'surplus'): ['to'],
#  ('surplus', 'to'): ['give'],
#  ('to', 'give'): ['you'],
#  ('give', 'you'): ['confidence,'],
#  ('you', 'confidence,'): ['a'],
#  ('confidence,', 'a'): ['little'],
#  ('little', 'too'): ['much'],
#  ('too', 'much'): ['work', 'to'],
#  ('much', 'work'): ['each'],
#  ('work', 'each'): ['day,'],
#  ('each', 'day,'): ['enthusiasm'],
#  ('day,', 'enthusiasm'): ['for'],
#  ('enthusiasm', 'for'): ['your'],
#  ('for', 'your'): ['work,', 'life.', 'dysfunction.'],
#  ('your', 'work,'): ['a'],
#  ('work,', 'a'): ['substantial'],
#  ('a', 'substantial'): ['share'],
#  ('substantial', 'share'): ['of'],
#  ('share', 'of'): ['good'],
#  ('of', 'good'): ['health,'],
#  ('good', 'health,'): ['a'],
#  ('health,', 'a'): ['couple'],
#  ('a', 'couple'): ['of'],
#  ('couple', 'of'): ['real'],
#  ('of', 'real'): ['friends'],
#  ('real', 'friends'): ['and'],
#  ('friends', 'and'): ['a'],
#  ('and', 'a'): ['wife', 'friend,', 'nap'],
#  ('a', 'wife'): ['and'],
#  ('wife', 'and'): ['children'],
#  ('and', 'children'): ['to'],
#  ('children', 'to'): ['share'],
#  ('to', 'share'): ['life’s', '-'],
#  ('share', 'life’s'): ['beauty'],
#  ('life’s', 'beauty'): ['with'],
#  ('beauty', 'with'): ['you.'],
#  ('with', 'you.'): ['For'],
#  ('you.', 'For'): ['me'],
#  ('For', 'me'): ['it'],
#  ('me', 'it'): ['is'],
#  ('is', 'sufficient'): ['to'],
#  ('sufficient', 'to'): ['have'],
#  ('to', 'have'): ['a'],
#  ('have', 'a'): ['corner'],
#  ('a', 'corner'): ['by'],
#  ('corner', 'by'): ['my'],
#  ('by', 'my'): ['hearth,'],
#  ('my', 'hearth,'): ['a'],
#  ('hearth,', 'a'): ['book'],
#  ('a', 'book'): ['and'],
#  ('book', 'and'): ['a'],
#  ('a', 'friend,'): ['and'],
#  ('friend,', 'and'): ['a'],
#  ('a', 'nap'): ['undisturbed'],
#  ('nap', 'undisturbed'): ['by'],
#  ('undisturbed', 'by'): ['creditors'],
#  ('by', 'creditors'): ['or'],
#  ('creditors', 'or'): ['grief.'],
#  ('or', 'grief.'): ['You'],
#  ('grief.', 'You'): ['cannot'],
#  ('You', 'cannot'): ['judge'],
#  ('cannot', 'judge'): ['what', 'what'],
#  ('judge', 'what'): ['should', 'should'],
#  ('what', 'should'): ['bring', 'bring'],
#  ('should', 'bring'): ['others', 'you'],
#  ('bring', 'others'): ['joy,'],
#  ('others', 'joy,'): ['and'],
#  ('joy,', 'and'): ['others'],
#  ('and', 'others'): ['cannot'],
#  ('others', 'cannot'): ['judge'],
#  ('bring', 'you'): ['joy.'],
#  ('you', 'joy.'): ['The'],
#  ('joy.', 'The'): ['art'],
#  ('The', 'art'): ['of'],
#  ('art', 'of'): ['living'],
#  ('of', 'living'): ['lies', 'every'],
#  ('living', 'lies'): ['less'],
#  ('lies', 'less'): ['in'],
#  ('less', 'in'): ['eliminating'],
#  ('in', 'eliminating'): ['our'],
#  ('eliminating', 'our'): ['troubles'],
#  ('our', 'troubles'): ['than'],
#  ('troubles', 'than'): ['growing'],
#  ('than', 'growing'): ['with'],
#  ('growing', 'with'): ['them.'],
#  ('with', 'them.'): ['Be'],
#  ('them.', 'Be'): ['happy'],
#  ('Be', 'happy'): ['with'],
#  ('you', 'have.'): ['Be', 'True'],
#  ('have.', 'Be'): ['excited'],
#  ('Be', 'excited'): ['about'],
#  ('excited', 'about'): ['what'],
#  ('about', 'what'): ['you'],
#  ('you', 'want.'): ['Our', 'It', 'Happiness'],
#  ('want.', 'Our'): ['capacity'],
#  ('Our', 'capacity'): ['to'],
#  ('capacity', 'to'): ['draw'],
#  ('to', 'draw'): ['happiness'],
#  ('draw', 'happiness'): ['from'],
#  ('happiness', 'from'): ['aesthetic'],
#  ('from', 'aesthetic'): ['objects'],
#  ('aesthetic', 'objects'): ['or'],
#  ('objects', 'or'): ['material'],
#  ('or', 'material'): ['goods'],
#  ('material', 'goods'): ['in'],
#  ('goods', 'in'): ['fact'],
#  ('in', 'fact'): ['seems'],
#  ('fact', 'seems'): ['critically'],
#  ('seems', 'critically'): ['dependent'],
#  ('critically', 'dependent'): ['on'],
#  ('dependent', 'on'): ['our'],
#  ('on', 'our'): ['first', 'car'],
#  ('our', 'first'): ['satisfying'],
#  ('first', 'satisfying'): ['a'],
#  ('satisfying', 'a'): ['more'],
#  ('a', 'more'): ['important'],
#  ('more', 'important'): ['range'],
#  ('important', 'range'): ['of'],
#  ('range', 'of'): ['emotional'],
#  ('of', 'emotional'): ['or'],
#  ('emotional', 'or'): ['psychological'],
#  ('or', 'psychological'): ['needs,'],
#  ('psychological', 'needs,'): ['among'],
#  ('needs,', 'among'): ['them'],
#  ('among', 'them'): ['the'],
#  ('them', 'the'): ['need'],
#  ('the', 'need'): ['for'],
#  ('need', 'for'): ['understanding,', 'forgiveness'],
#  ('for', 'understanding,'): ['for'],
#  ('understanding,', 'for'): ['love,'],
#  ('for', 'love,'): ['expression'],
#  ('love,', 'expression'): ['and'],
#  ('expression', 'and'): ['respect.'],
#  ('and', 'respect.'): ['If'],
#  ('respect.', 'If'): ['you'],
#  ('you', 'start'): ['to'],
#  ('start', 'to'): ['think'],
#  ('to', 'think'): ['the', '-'],
#  ('think', 'the'): ['problem'],
#  ('the', 'problem'): ['is'],
#  ('problem', 'is'): ['‘out'],
#  ('is', '‘out'): ['there,’'],
#  ('‘out', 'there,’'): ['stop'],
#  ('there,’', 'stop'): ['yourself.'],
#  ('stop', 'yourself.'): ['That'],
#  ('yourself.', 'That'): ['thought'],
#  ('That', 'thought'): ['is'],
#  ('thought', 'is'): ['the'],
#  ('is', 'the'): ['problem.',
#   'spiritual',
#   'meaning',
#   'denial',
#   'experience',
#   'price',
#   'source',
#   'secret',
#   'fountain',
#   'road',
#   'nourishment',
#   'music',
#   'dizziness',
#   'tomorrow',
#   'feeling'],
#  ('the', 'problem.'): ['Happiness'],
#  ('problem.', 'Happiness'): ['cannot'],
#  ('Happiness', 'cannot'): ['be'],
#  ('cannot', 'be'): ['traveled', 'without'],
#  ('be', 'traveled'): ['to,'],
#  ('traveled', 'to,'): ['owned,'],
#  ('to,', 'owned,'): ['earned,'],
#  ('owned,', 'earned,'): ['worn'],
#  ('earned,', 'worn'): ['or'],
#  ('worn', 'or'): ['consumed.'],
#  ('or', 'consumed.'): ['Happiness'],
#  ('consumed.', 'Happiness'): ['is'],
#  ('Happiness', 'is'): ['the',
#   'not',
#   'the',
#   'not',
#   'that',
#   'wanting',
#   'the',
#   'where'],
#  ('the', 'spiritual'): ['experience'],
#  ('spiritual', 'experience'): ['of'],
#  ('experience', 'of'): ['living', 'loving'],
#  ('living', 'every'): ['minute'],
#  ('every', 'minute'): ['with'],
#  ('minute', 'with'): ['love,'],
#  ('with', 'love,'): ['grace,'],
#  ('love,', 'grace,'): ['and'],
#  ('grace,', 'and'): ['gratitude.'],
#  ('and', 'gratitude.'): ['Happiness'],
#  ('gratitude.', 'Happiness'): ['is'],
#  ('is', 'not'): ['a',
#   'to',
#   'attained',
#   'having',
#   'measured',
#   'just',
#   'learning',
#   'always',
#   'happiness'],
#  ('not', 'a'): ['station'],
#  ('a', 'station'): ['you'],
#  ('station', 'you'): ['arrive'],
#  ('you', 'arrive'): ['at,'],
#  ('arrive', 'at,'): ['but'],
#  ('at,', 'but'): ['a'],
#  ('but', 'a'): ['manner', 'play...'],
#  ('a', 'manner'): ['of'],
#  ('manner', 'of'): ['traveling.'],
#  ('of', 'traveling.'): ['Happiness'],
#  ('traveling.', 'Happiness'): ['is'],
#  ('the', 'meaning'): ['and'],
#  ('meaning', 'and'): ['the'],
#  ('and', 'the'): ['purpose', 'life', 'word', 'men', 'wisdom'],
#  ('the', 'purpose'): ['of'],
#  ('purpose', 'of'): ['life,'],
#  ('of', 'life,'): ['the'],
#  ('life,', 'the'): ['whole'],
#  ('the', 'whole'): ['aim', 'movie.'],
#  ('whole', 'aim'): ['and'],
#  ('aim', 'and'): ['end'],
#  ('and', 'end'): ['of'],
#  ('end', 'of'): ['human', 'the'],
#  ('of', 'human'): ['existence.'],
#  ('human', 'existence.'): ['Security'],
#  ('existence.', 'Security'): ['is'],
#  ('Security', 'is'): ['when'],
#  ('is', 'when'): ['everything'],
#  ('when', 'everything'): ['is'],
#  ('everything', 'is'): ['settled,', 'a'],
#  ('is', 'settled,'): ['when'],
#  ('settled,', 'when'): ['nothing'],
#  ('when', 'nothing'): ['can'],
#  ('nothing', 'can'): ['happen'],
#  ('can', 'happen'): ['to'],
#  ('happen', 'to'): ['you;'],
#  ('to', 'you;'): ['security'],
#  ('you;', 'security'): ['is'],
#  ('security', 'is'): ['the'],
#  ('the', 'denial'): ['of'],
#  ('denial', 'of'): ['life.'],
#  ('of', 'life.'): ['Focus', 'It'],
#  ('life.', 'Focus'): ['on'],
#  ('Focus', 'on'): ['the'],
#  ('on', 'the'): ['journey,', 'back.'],
#  ('the', 'journey,'): ['not'],
#  ('journey,', 'not'): ['the'],
#  ('not', 'the'): ['destination.', 'final'],
#  ('the', 'destination.'): ['Joy'],
#  ('destination.', 'Joy'): ['is'],
#  ('Joy', 'is'): ['found'],
#  ('is', 'found'): ['not'],
#  ('found', 'not'): ['in'],
#  ('not', 'in'): ['finishing', 'being'],
#  ('in', 'finishing'): ['an'],
#  ('finishing', 'an'): ['activity'],
#  ('an', 'activity'): ['but'],
#  ('activity', 'but'): ['in'],
#  ('but', 'in'): ['doing'],
#  ('in', 'doing'): ['it.'],
#  ('doing', 'it.'): ['Thousands'],
#  ('it.', 'Thousands'): ['of'],
#  ('Thousands', 'of'): ['candles'],
#  ('of', 'candles'): ['can'],
#  ('candles', 'can'): ['be'],
#  ('can', 'be'): ['lit', 'quiet,'],
#  ('be', 'lit'): ['from'],
#  ('lit', 'from'): ['a'],
#  ('from', 'a'): ['single'],
#  ('a', 'single'): ['candle,'],
#  ('single', 'candle,'): ['and'],
#  ('candle,', 'and'): ['the'],
#  ('the', 'life'): ['of'],
#  ('life', 'of'): ['the'],
#  ('the', 'candle'): ['will'],
#  ('candle', 'will'): ['not'],
#  ('will', 'not'): ['be'],
#  ('not', 'be'): ['shortened.', 'apparent'],
#  ('be', 'shortened.'): ['Happiness'],
#  ('shortened.', 'Happiness'): ['never'],
#  ('Happiness', 'never'): ['decreases'],
#  ('never', 'decreases'): ['by'],
#  ('decreases', 'by'): ['being'],
#  ('by', 'being'): ['shared.'],
#  ('being', 'shared.'): ['The'],
#  ('shared.', 'The'): ['best'],
#  ('The', 'best'): ['remedy'],
#  ('best', 'remedy'): ['for'],
#  ('remedy', 'for'): ['those'],
#  ('for', 'those'): ['who'],
#  ('those', 'who'): ['are', 'can'],
#  ('who', 'are'): ['afraid,', 'you'],
#  ('are', 'afraid,'): ['lonely'],
#  ('afraid,', 'lonely'): ['or'],
#  ('lonely', 'or'): ['unhappy'],
#  ('or', 'unhappy'): ['is'],
#  ('unhappy', 'is'): ['to'],
#  ('to', 'go'): ['outside,'],
#  ('go', 'outside,'): ['somewhere'],
#  ('outside,', 'somewhere'): ['where'],
#  ('somewhere', 'where'): ['they'],
#  ('where', 'they'): ['can'],
#  ('they', 'can'): ['be'],
#  ('be', 'quiet,'): ['alone'],
#  ('quiet,', 'alone'): ['with'],
#  ('alone', 'with'): ['the'],
#  ('the', 'heavens,'): ['nature'],
#  ('heavens,', 'nature'): ['and'],
#  ('nature', 'and'): ['God.', 'personal'],
#  ('and', 'God.'): ['As'],
#  ('God.', 'As'): ['long'],
#  ('As', 'long'): ['as'],
#  ('long', 'as'): ['this'],
#  ('as', 'this'): ['exists,'],
#  ('this', 'exists,'): ['and'],
#  ('exists,', 'and'): ['it'],
#  ('and', 'it'): ['certainly'],
#  ('it', 'certainly'): ['always'],
#  ('certainly', 'always'): ['will,'],
#  ('always', 'will,'): ['then'],
#  ('will,', 'then'): ['there'],
#  ('then', 'there'): ['will'],
#  ('there', 'will'): ['be', 'be'],
#  ('be', 'comfort'): ['for'],
#  ('comfort', 'for'): ['every'],
#  ('for', 'every'): ['sorrow,'],
#  ('every', 'sorrow,'): ['whatever'],
#  ('sorrow,', 'whatever'): ['the'],
#  ('whatever', 'the'): ['circumstances'],
#  ('the', 'circumstances'): ['may'],
#  ('circumstances', 'may'): ['be.'],
#  ('may', 'be.'): ['In'],
#  ('be.', 'In'): ['our'],
#  ('In', 'our'): ['lives,', 'daily'],
#  ('our', 'lives,'): ['change', 'as'],
#  ('lives,', 'change'): ['is'],
#  ('change', 'is'): ['unavoidable,'],
#  ('is', 'unavoidable,'): ['loss'],
#  ('unavoidable,', 'loss'): ['is'],
#  ('loss', 'is'): ['unavoidable.'],
#  ('is', 'unavoidable.'): ['In'],
#  ('unavoidable.', 'In'): ['the'],
#  ('In', 'the'): ['adaptability', 'midst'],
#  ('the', 'adaptability'): ['and'],
#  ('adaptability', 'and'): ['ease'],
#  ('and', 'ease'): ['with'],
#  ('ease', 'with'): ['which'],
#  ('with', 'which'): ['we'],
#  ('which', 'we'): ['experience'],
#  ('we', 'experience'): ['change,', 'Heaven'],
#  ('experience', 'change,'): ['lies'],
#  ('change,', 'lies'): ['our'],
#  ('lies', 'our'): ['happiness'],
#  ('our', 'happiness'): ['and'],
#  ('happiness', 'and'): ['freedom.', 'creativity.'],
#  ('and', 'freedom.'): ['Live'],
#  ('freedom.', 'Live'): ['with'],
#  ('Live', 'with'): ['intention.'],
#  ('with', 'intention.'): ['Walk'],
#  ('intention.', 'Walk'): ['to'],
#  ('Walk', 'to'): ['the'],
#  ('to', 'the'): ['edge.', 'light'],
#  ('the', 'edge.'): ['Listen'],
#  ('edge.', 'Listen'): ['hard.'],
#  ('Listen', 'hard.'): ['Practice'],
#  ('hard.', 'Practice'): ['wellness.'],
#  ('Practice', 'wellness.'): ['Play'],
#  ('wellness.', 'Play'): ['with'],
#  ('Play', 'with'): ['abandon.'],
#  ('with', 'abandon.'): ['Laugh.'],
#  ('abandon.', 'Laugh.'): ['Choose'],
#  ('Laugh.', 'Choose'): ['with'],
#  ('Choose', 'with'): ['no'],
#  ('with', 'no'): ['regret.'],
#  ('no', 'regret.'): ['Do'],
#  ('regret.', 'Do'): ['what'],
#  ('Do', 'what'): ['you', 'you'],
#  ('you', 'love.'): ['Live'],
#  ('love.', 'Live'): ['as'],
#  ('Live', 'as'): ['if'],
#  ('as', 'if'): ['this', 'you’ll', 'you’ll'],
#  ('if', 'this'): ['is'],
#  ('this', 'is'): ['all'],
#  ('is', 'all'): ['there'],
#  ('all', 'there'): ['is.'],
#  ('there', 'is.'): ['You'],
#  ('is.', 'You'): ['never'],
#  ('You', 'never'): ['regret'],
#  ('never', 'regret'): ['being'],
#  ('regret', 'being'): ['kind.'],
#  ('being', 'kind.'): ['They'],
#  ('kind.', 'They'): ['who'],
#  ('They', 'who'): ['can'],
#  ('who', 'can'): ['give', 'give'],
#  ('can', 'give'): ['up', 'without'],
#  ('give', 'up'): ['essential'],
#  ('up', 'essential'): ['liberty'],
#  ('essential', 'liberty'): ['to'],
#  ('liberty', 'to'): ['obtain'],
#  ('to', 'obtain'): ['a'],
#  ('obtain', 'a'): ['little'],
#  ('little', 'temporary'): ['safety,'],
#  ('temporary', 'safety,'): ['deserve'],
#  ('safety,', 'deserve'): ['neither'],
#  ('deserve', 'neither'): ['liberty'],
#  ('neither', 'liberty'): ['nor'],
#  ('liberty', 'nor'): ['safety.'],
#  ('nor', 'safety.'): ['Forgiveness'],
#  ('safety.', 'Forgiveness'): ['does'],
#  ('Forgiveness', 'does'): ['not'],
#  ('does', 'not'): ['change', 'kill'],
#  ('not', 'change'): ['the'],
#  ('change', 'the'): ['past,', 'past', 'things', 'things'],
#  ('the', 'past,'): ['but', 'worry'],
#  ('past,', 'but'): ['it'],
#  ('but', 'it'): ['does'],
#  ('it', 'does'): ['enlarge'],
#  ('does', 'enlarge'): ['the'],
#  ('enlarge', 'the'): ['future.'],
#  ('the', 'future.'): ['The', 'We'],
#  ('future.', 'The'): ['secret'],
#  ('The', 'secret'): ['of'],
#  ('secret', 'of'): ['health', 'perpetual'],
#  ('of', 'health'): ['for'],
#  ('health', 'for'): ['both'],
#  ('for', 'both'): ['mind'],
#  ('both', 'mind'): ['and'],
#  ('mind', 'and'): ['body'],
#  ('and', 'body'): ['is'],
#  ('body', 'is'): ['not'],
#  ('not', 'to'): ['mourn', 'be', 'focus', 'charge'],
#  ('to', 'mourn'): ['for'],
#  ('mourn', 'for'): ['the'],
#  ('past,', 'worry'): ['about'],
#  ('worry', 'about'): ['the'],
#  ('about', 'the'): ['future,'],
#  ('the', 'future,'): ['or'],
#  ('future,', 'or'): ['anticipate'],
#  ('or', 'anticipate'): ['troubles,'],
#  ('anticipate', 'troubles,'): ['but'],
#  ('troubles,', 'but'): ['to'],
#  ('but', 'to'): ['live'],
#  ('live', 'in'): ['the'],
#  ('the', 'present'): ['moment'],
#  ('present', 'moment'): ['wisely'],
#  ('moment', 'wisely'): ['and'],
#  ('wisely', 'and'): ['earnestly.'],
#  ('and', 'earnestly.'): ['True'],
#  ('earnestly.', 'True'): ['happiness'],
#  ('True', 'happiness'): ['is'],
#  ('happiness', 'is'): ['not'],
#  ('not', 'attained'): ['through'],
#  ('attained', 'through'): ['self-gratification,'],
#  ('through', 'self-gratification,'): ['but'],
#  ('self-gratification,', 'but'): ['through'],
#  ('but', 'through'): ['fidelity'],
#  ('through', 'fidelity'): ['to'],
#  ('fidelity', 'to'): ['a'],
#  ('to', 'a'): ['worthy', 'star.'],
#  ('a', 'worthy'): ['purpose.'],
#  ('worthy', 'purpose.'): ['Most'],
#  ('purpose.', 'Most'): ['of'],
#  ('Most', 'of'): ['us'],
#  ('of', 'us'): ['miss'],
#  ('us', 'miss'): ['out'],
#  ('miss', 'out'): ['on'],
#  ('out', 'on'): ['life’s'],
#  ('on', 'life’s'): ['big'],
#  ('life’s', 'big'): ['prizes.'],
#  ('big', 'prizes.'): ['The'],
#  ('prizes.', 'The'): ['Pulitzer.'],
#  ('The', 'Pulitzer.'): ['The'],
#  ('Pulitzer.', 'The'): ['Nobel.'],
#  ('The', 'Nobel.'): ['Oscars.'],
#  ('Nobel.', 'Oscars.'): ['The'],
#  ('Oscars.', 'The'): ['World'],
#  ('The', 'World'): ['Cup.'],
#  ('World', 'Cup.'): ['But'],
#  ('Cup.', 'But'): ['we’re'],
#  ('But', 'we’re'): ['all'],
#  ('we’re', 'all'): ['eligible'],
#  ('all', 'eligible'): ['for'],
#  ('eligible', 'for'): ['life’s'],
#  ('for', 'life’s'): ['smaller'],
#  ('life’s', 'smaller'): ['prizes...'],
#  ('smaller', 'prizes...'): ['A'],
#  ('prizes...', 'A'): ['pat'],
#  ('A', 'pat'): ['on'],
#  ('pat', 'on'): ['the'],
#  ('the', 'back.'): ['A'],
#  ('back.', 'A'): ['kiss'],
#  ('A', 'kiss'): ['behind'],
#  ('kiss', 'behind'): ['the'],
#  ('behind', 'the'): ['ear.'],
#  ('the', 'ear.'): ['A'],
#  ('ear.', 'A'): ['four-pound'],
#  ('A', 'four-pound'): ['bass.'],
#  ('four-pound', 'bass.'): ['A'],
#  ('bass.', 'A'): ['full'],
#  ('A', 'full'): ['moon.'],
#  ('full', 'moon.'): ['An'],
#  ('moon.', 'An'): ['empty'],
#  ('An', 'empty'): ['parking'],
#  ('empty', 'parking'): ['space.'],
#  ('parking', 'space.'): ['A'],
#  ('space.', 'A'): ['crackling'],
#  ('A', 'crackling'): ['fire.'],
#  ('crackling', 'fire.'): ['A'],
#  ('fire.', 'A'): ['great'],
#  ('A', 'great'): ['meal.'],
#  ('great', 'meal.'): ['A'],
#  ('meal.', 'A'): ['glorious'],
#  ('A', 'glorious'): ['sunset.'],
#  ('glorious', 'sunset.'): ['Hot'],
#  ('sunset.', 'Hot'): ['soup.'],
#  ('Hot', 'soup.'): ['Cold'],
#  ('soup.', 'Cold'): ['beer.'],
#  ('Cold', 'beer.'): ['Money'],
#  ('beer.', 'Money'): ['is'],
#  ('Money', 'is'): ['neither'],
#  ('is', 'neither'): ['my'],
#  ('neither', 'my'): ['god'],
#  ('my', 'god'): ['nor'],
#  ('god', 'nor'): ['my'],
#  ('nor', 'my'): ['devil.'],
#  ('my', 'devil.'): ['It'],
#  ('devil.', 'It'): ['is'],
#  ('It', 'is'): ['a', 'far', 'appreciating', 'our', 'not', 'always'],
#  ('a', 'form'): ['of'],
#  ('form', 'of'): ['energy'],
#  ('of', 'energy'): ['that'],
#  ('energy', 'that'): ['tends'],
#  ('that', 'tends'): ['to'],
#  ('tends', 'to'): ['make'],
#  ('to', 'make'): ['us', 'themselves'],
#  ('make', 'us'): ['more'],
#  ('us', 'more'): ['of'],
#  ('more', 'of'): ['who'],
#  ('of', 'who'): ['we'],
#  ('who', 'we'): ['already'],
#  ('we', 'already'): ['are,'],
#  ('already', 'are,'): ['whether'],
#  ('are,', 'whether'): ['it’s'],
#  ('whether', 'it’s'): ['greedy'],
#  ('it’s', 'greedy'): ['or'],
#  ('greedy', 'or'): ['loving.'],
#  ('or', 'loving.'): ['The'],
#  ('loving.', 'The'): ['need'],
#  ('The', 'need'): ['for'],
#  ('for', 'forgiveness'): ['is'],
#  ('forgiveness', 'is'): ['an'],
#  ('is', 'an'): ['illusion.', 'opportunity,', 'adventure,'],
#  ('an', 'illusion.'): ['There'],
#  ('illusion.', 'There'): ['is'],
#  ('nothing', 'to'): ['forgive.'],
#  ('to', 'forgive.'): ['Blessed'],
#  ('forgive.', 'Blessed'): ['are'],
#  ('Blessed', 'are'): ['those'],
#  ('are', 'those'): ['who'],
#  ('give', 'without'): ['remembering'],
#  ('without', 'remembering'): ['and'],
#  ('remembering', 'and'): ['take'],
#  ('and', 'take'): ['without'],
#  ('take', 'without'): ['forgetting.'],
#  ('without', 'forgetting.'): ['Reflect'],
#  ('forgetting.', 'Reflect'): ['upon'],
#  ('Reflect', 'upon'): ['you'],
#  ('upon', 'you'): ['present'],
#  ('you', 'present'): ['blessings,'],
#  ('present', 'blessings,'): ['of'],
#  ('blessings,', 'of'): ['which'],
#  ('of', 'which'): ['every', 'all'],
#  ('which', 'every'): ['man'],
#  ('every', 'man'): ['has'],
#  ('man', 'has'): ['many'],
#  ('has', 'many'): ['-'],
#  ('many', '-'): ['not'],
#  ('-', 'not'): ['on'],
#  ('not', 'on'): ['your'],
#  ('on', 'your'): ['past'],
#  ('your', 'past'): ['misfortunes,'],
#  ('past', 'misfortunes,'): ['of'],
#  ('misfortunes,', 'of'): ['which'],
#  ('which', 'all'): ['men'],
#  ('all', 'men'): ['have'],
#  ('men', 'have'): ['some.'],
#  ('have', 'some.'): ['Even'],
#  ('some.', 'Even'): ['a'],
#  ('Even', 'a'): ['happy'],
#  ('a', 'happy'): ['life'],
#  ('happy', 'life'): ['cannot'],
#  ('life', 'cannot'): ['be'],
#  ('be', 'without'): ['a'],
#  ('a', 'measure'): ['of'],
#  ('measure', 'of'): ['darkness,'],
#  ('of', 'darkness,'): ['and'],
#  ('darkness,', 'and'): ['the'],
#  ('the', 'word'): ['happy'],
#  ('word', 'happy'): ['would'],
#  ('happy', 'would'): ['lose'],
#  ('would', 'lose'): ['its'],
#  ('lose', 'its'): ['meaning'],
#  ('its', 'meaning'): ['if'],
#  ('meaning', 'if'): ['it'],
#  ('if', 'it'): ['were'],
#  ('it', 'were'): ['not'],
#  ('were', 'not'): ['balanced'],
#  ('not', 'balanced'): ['by'],
#  ('balanced', 'by'): ['sadness.'],
#  ('by', 'sadness.'): ['It'],
#  ('sadness.', 'It'): ['is'],
#  ('is', 'far'): ['better'],
#  ('far', 'better'): ['to'],
#  ('better', 'to'): ['take'],
#  ('to', 'take'): ['things', 'next...'],
#  ('take', 'things'): ['as'],
#  ('things', 'as'): ['they'],
#  ('as', 'they'): ['come'],
#  ('they', 'come'): ['along'],
#  ('come', 'along'): ['with'],
#  ('along', 'with'): ['patience'],
#  ('with', 'patience'): ['and'],
#  ('patience', 'and'): ['equanimity.'],
#  ('and', 'equanimity.'): ['Much'],
#  ('equanimity.', 'Much'): ['of'],
#  ('Much', 'of'): ['the'],
#  ('the', 'stress'): ['that'],
#  ('stress', 'that'): ['people'],
#  ('that', 'people'): ['feel'],
#  ('people', 'feel'): ['doesn’t'],
#  ('feel', 'doesn’t'): ['come'],
#  ('doesn’t', 'come'): ['from'],
#  ('come', 'from'): ['having', 'avoiding'],
#  ('from', 'having'): ['too'],
#  ('having', 'too'): ['much'],
#  ('much', 'to'): ['do.'],
#  ('to', 'do.'): ['It'],
#  ('do.', 'It'): ['comes'],
#  ('It', 'comes'): ['from'],
#  ('from', 'not'): ['finishing'],
#  ('not', 'finishing'): ['what'],
#  ('finishing', 'what'): ['they’ve'],
#  ('what', 'they’ve'): ['started.'],
#  ('they’ve', 'started.'): ['He'],
#  ('started.', 'He'): ['who'],
#  ('He', 'who'): ['lives'],
#  ('who', 'lives'): ['in'],
#  ('lives', 'in'): ['harmony', 'harmony'],
#  ('in', 'harmony'): ['with', 'with'],
#  ('harmony', 'with'): ['himself', 'the'],
#  ('with', 'himself'): ['lives'],
#  ('himself', 'lives'): ['in'],
#  ('the', 'universe.'): ['If'],
#  ('universe.', 'If'): ['you'],
#  ('want', 'others'): ['to'],
#  ('others', 'to'): ['be'],
#  ('happy,', 'practice'): ['compassion.', 'compassion.'],
#  ('practice', 'compassion.'): ['If', 'All'],
#  ('compassion.', 'If'): ['you'],
#  ('compassion.', 'All'): ['the'],
#  ('All', 'the'): ['world’s'],
#  ('the', 'world’s'): ['a'],
#  ('world’s', 'a'): ['stage,'],
#  ('a', 'stage,'): ['and'],
#  ('stage,', 'and'): ['the'],
#  ('the', 'men'): ['and'],
#  ('men', 'and'): ['women'],
#  ('and', 'women'): ['merely'],
#  ('women', 'merely'): ['players.'],
#  ('merely', 'players.'): ['They'],
#  ('players.', 'They'): ['have'],
#  ('They', 'have'): ['their'],
#  ('have', 'their'): ['exits'],
#  ('their', 'exits'): ['and'],
#  ('exits', 'and'): ['their'],
#  ('and', 'their'): ['entrances;'],
#  ('their', 'entrances;'): ['and'],
#  ('entrances;', 'and'): ['one'],
#  ('and', 'one'): ['man'],
#  ('one', 'man'): ['in'],
#  ('man', 'in'): ['his'],
#  ('in', 'his'): ['time'],
#  ('his', 'time'): ['plays'],
#  ('time', 'plays'): ['many'],
#  ('plays', 'many'): ['parts.'],
#  ('many', 'parts.'): ['Dream'],
#  ('parts.', 'Dream'): ['as'],
#  ('Dream', 'as'): ['if'],
#  ('if', 'you’ll'): ['live', 'die'],
#  ('you’ll', 'live'): ['forever,'],
#  ('live', 'forever,'): ['live'],
#  ('forever,', 'live'): ['as'],
#  ('live', 'as'): ['if'],
#  ('you’ll', 'die'): ['today.'],
#  ('die', 'today.'): ['When'],
#  ('today.', 'When'): ['one'],
#  ('When', 'one'): ['door'],
#  ('one', 'door'): ['of'],
#  ('door', 'of'): ['happiness'],
#  ('of', 'happiness'): ['closes,'],
#  ('happiness', 'closes,'): ['another'],
#  ('closes,', 'another'): ['opens,'],
#  ('another', 'opens,'): ['but'],
#  ('opens,', 'but'): ['often'],
#  ('but', 'often'): ['we'],
#  ('often', 'we'): ['look'],
#  ('we', 'look'): ['so'],
#  ('look', 'so'): ['long'],
#  ('so', 'long'): ['at'],
#  ('long', 'at'): ['the'],
#  ('at', 'the'): ['closed'],
#  ('the', 'closed'): ['door'],
#  ('closed', 'door'): ['that'],
#  ('door', 'that'): ['we'],
#  ('that', 'we'): ['do', 'take', 'share', 'are', 'are', 'don’t', 'need'],
#  ('we', 'do'): ['not'],
#  ('do', 'not'): ['see', 'destroy', 'seek'],
#  ('not', 'see'): ['the'],
#  ('see', 'the'): ['one'],
#  ('the', 'one'): ['that'],
#  ('one', 'that'): ['has'],
#  ('that', 'has'): ['been'],
#  ('has', 'been'): ['opened'],
#  ('been', 'opened'): ['for'],
#  ('opened', 'for'): ['us.'],
#  ('for', 'us.'): ['Happiness'],
#  ('us.', 'Happiness'): ['is'],
#  ('not', 'having'): ['what'],
#  ('having', 'what'): ['you'],
#  ('want.', 'It'): ['is'],
#  ('is', 'appreciating'): ['what'],
#  ('appreciating', 'what'): ['you'],
#  ('have.', 'True'): ['happiness...'],
#  ('True', 'happiness...'): ['arises,'],
#  ('happiness...', 'arises,'): ['in'],
#  ('arises,', 'in'): ['the'],
#  ('the', 'first'): ['place,', 'or'],
#  ('first', 'place,'): ['from'],
#  ('place,', 'from'): ['the'],
#  ('from', 'the'): ['enjoyment', 'achievement'],
#  ('the', 'enjoyment'): ['of'],
#  ('enjoyment', 'of'): ['one’s'],
#  ('of', 'one’s'): ['self.', 'values.'],
#  ('one’s', 'self.'): ['Happiness'],
#  ('self.', 'Happiness'): ['is'],
#  ('is', 'that'): ['state', 'we'],
#  ('that', 'state'): ['of'],
#  ('state', 'of'): ['consciousness'],
#  ('of', 'consciousness'): ['which'],
#  ('consciousness', 'which'): ['proceeds'],
#  ('which', 'proceeds'): ['from'],
#  ('proceeds', 'from'): ['the'],
#  ('the', 'achievement'): ['of'],
#  ('achievement', 'of'): ['one’s'],
#  ('one’s', 'values.'): ['All'],
#  ('values.', 'All'): ['this'],
#  ('All', 'this'): ['world'],
#  ('this', 'world'): ['is'],
#  ('world', 'is'): ['but'],
#  ('is', 'but'): ['a'],
#  ('a', 'play...'): ['be'],
#  ('play...', 'be'): ['thou'],
#  ('be', 'thou'): ['the'],
#  ('thou', 'the'): ['joyful'],
#  ('the', 'joyful'): ['player.'],
#  ('joyful', 'player.'): ['Life'],
#  ('player.', 'Life'): ['is'],
#  ('an', 'opportunity,'): ['benefit'],
#  ('opportunity,', 'benefit'): ['from'],
#  ('benefit', 'from'): ['it.'],
#  ('from', 'it.'): ['Life'],
#  ('it.', 'Life'): ['is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is'],
#  ...}

# %%
text_gen = MarkovText(corpus, k=3)

text_gen.get_term_dict()
# Out:
# {('Healing', 'comes', 'from'): ['taking'],
#  ('comes', 'from', 'taking'): ['responsibility:'],
#  ('from', 'taking', 'responsibility:'): ['to'],
#  ('taking', 'responsibility:', 'to'): ['realize'],
#  ('responsibility:', 'to', 'realize'): ['that'],
#  ('to', 'realize', 'that'): ['it'],
#  ('realize', 'that', 'it'): ['is'],
#  ('that', 'it', 'is'): ['you', 'not'],
#  ('it', 'is', 'you'): ['-'],
#  ('is', 'you', '-'): ['and'],
#  ('you', '-', 'and'): ['no'],
#  ('-', 'and', 'no'): ['one'],
#  ('and', 'no', 'one'): ['else'],
#  ('no', 'one', 'else'): ['-'],
#  ('one', 'else', '-'): ['that'],
#  ('else', '-', 'that'): ['creates'],
#  ('-', 'that', 'creates'): ['your'],
#  ('that', 'creates', 'your'): ['thoughts,'],
#  ('creates', 'your', 'thoughts,'): ['your'],
#  ('your', 'thoughts,', 'your'): ['feelings,'],
#  ('thoughts,', 'your', 'feelings,'): ['and'],
#  ('your', 'feelings,', 'and'): ['your'],
#  ('feelings,', 'and', 'your'): ['actions.'],
#  ('and', 'your', 'actions.'): ['Life'],
#  ('your', 'actions.', 'Life'): ['is'],
#  ('actions.', 'Life', 'is'): ['a'],
#  ('Life', 'is', 'a'): ['journey',
#   'dream,',
#   'challenge,',
#   'duty,',
#   'game,',
#   'promise,',
#   'song,',
#   'struggle,',
#   'tragedy,'],
#  ('is', 'a', 'journey'): ['and'],
#  ('a', 'journey', 'and'): ['if'],
#  ('journey', 'and', 'if'): ['you'],
#  ('and', 'if', 'you'): ['fall'],
#  ('if', 'you', 'fall'): ['in'],
#  ('you', 'fall', 'in'): ['love'],
#  ('fall', 'in', 'love'): ['with'],
#  ('in', 'love', 'with'): ['the', 'that'],
#  ('love', 'with', 'the'): ['journey'],
#  ('with', 'the', 'journey'): ['you'],
#  ('the', 'journey', 'you'): ['will'],
#  ('journey', 'you', 'will'): ['be'],
#  ('you', 'will', 'be'): ['in'],
#  ('will', 'be', 'in'): ['love'],
#  ('be', 'in', 'love'): ['forever.'],
#  ('in', 'love', 'forever.'): ['When'],
#  ('love', 'forever.', 'When'): ['you'],
#  ('forever.', 'When', 'you'): ['return'],
#  ('When', 'you', 'return'): ['to'],
#  ('you', 'return', 'to'): ['your'],
#  ('return', 'to', 'your'): ['old'],
#  ('to', 'your', 'old'): ['hometown,'],
#  ('your', 'old', 'hometown,'): ['you'],
#  ('old', 'hometown,', 'you'): ['find'],
#  ('hometown,', 'you', 'find'): ['it'],
#  ('you', 'find', 'it'): ['wasn’t'],
#  ('find', 'it', 'wasn’t'): ['the'],
#  ('it', 'wasn’t', 'the'): ['town'],
#  ('wasn’t', 'the', 'town'): ['you'],
#  ('the', 'town', 'you'): ['missed,'],
#  ('town', 'you', 'missed,'): ['but'],
#  ('you', 'missed,', 'but'): ['your'],
#  ('missed,', 'but', 'your'): ['childhood.'],
#  ('but', 'your', 'childhood.'): ['As'],
#  ('your', 'childhood.', 'As'): ['we'],
#  ('childhood.', 'As', 'we'): ['grow'],
#  ('As', 'we', 'grow'): ['old,'],
#  ('we', 'grow', 'old,'): ['the'],
#  ('grow', 'old,', 'the'): ['beauty'],
#  ('old,', 'the', 'beauty'): ['steals'],
#  ('the', 'beauty', 'steals'): ['inward.'],
#  ('beauty', 'steals', 'inward.'): ['Life'],
#  ('steals', 'inward.', 'Life'): ['begins'],
#  ('inward.', 'Life', 'begins'): ['as'],
#  ('Life', 'begins', 'as'): ['a'],
#  ('begins', 'as', 'a'): ['quest'],
#  ('as', 'a', 'quest'): ['of'],
#  ('a', 'quest', 'of'): ['the'],
#  ('quest', 'of', 'the'): ['child'],
#  ('of', 'the', 'child'): ['for'],
#  ('the', 'child', 'for'): ['the'],
#  ('child', 'for', 'the'): ['man,'],
#  ('for', 'the', 'man,'): ['and'],
#  ('the', 'man,', 'and'): ['ends'],
#  ('man,', 'and', 'ends'): ['as'],
#  ('and', 'ends', 'as'): ['a'],
#  ('ends', 'as', 'a'): ['journey'],
#  ('as', 'a', 'journey'): ['by'],
#  ('a', 'journey', 'by'): ['the'],
#  ('journey', 'by', 'the'): ['man'],
#  ('by', 'the', 'man'): ['to'],
#  ('the', 'man', 'to'): ['rediscover'],
#  ('man', 'to', 'rediscover'): ['the'],
#  ('to', 'rediscover', 'the'): ['child.'],
#  ('rediscover', 'the', 'child.'): ['Ultimately'],
#  ('the', 'child.', 'Ultimately'): ['your'],
#  ('child.', 'Ultimately', 'your'): ['greatest'],
#  ('Ultimately', 'your', 'greatest'): ['teacher'],
#  ('your', 'greatest', 'teacher'): ['is'],
#  ('greatest', 'teacher', 'is'): ['to'],
#  ('teacher', 'is', 'to'): ['live'],
#  ('is', 'to', 'live'): ['with'],
#  ('to', 'live', 'with'): ['an'],
#  ('live', 'with', 'an'): ['open'],
#  ('with', 'an', 'open'): ['heart.'],
#  ('an', 'open', 'heart.'): ['Doing'],
#  ('open', 'heart.', 'Doing'): ['what'],
#  ('heart.', 'Doing', 'what'): ['you'],
#  ('Doing', 'what', 'you'): ['like'],
#  ('what', 'you', 'like'): ['is'],
#  ('you', 'like', 'is'): ['freedom.'],
#  ('like', 'is', 'freedom.'): ['Liking'],
#  ('is', 'freedom.', 'Liking'): ['what'],
#  ('freedom.', 'Liking', 'what'): ['you'],
#  ('Liking', 'what', 'you'): ['do'],
#  ('what', 'you', 'do'): ['is'],
#  ('you', 'do', 'is'): ['happiness.'],
#  ('do', 'is', 'happiness.'): ['We'],
#  ('is', 'happiness.', 'We'): ['forge'],
#  ('happiness.', 'We', 'forge'): ['the'],
#  ('We', 'forge', 'the'): ['chains'],
#  ('forge', 'the', 'chains'): ['we'],
#  ('the', 'chains', 'we'): ['wear'],
#  ('chains', 'we', 'wear'): ['in'],
#  ('we', 'wear', 'in'): ['life.'],
#  ('wear', 'in', 'life.'): ['If'],
#  ('in', 'life.', 'If'): ['you'],
#  ('life.', 'If', 'you'): ['look'],
#  ('If', 'you', 'look'): ['to'],
#  ('you', 'look', 'to'): ['others'],
#  ('look', 'to', 'others'): ['for'],
#  ('to', 'others', 'for'): ['fulfillment,'],
#  ('others', 'for', 'fulfillment,'): ['you'],
#  ('for', 'fulfillment,', 'you'): ['will'],
#  ('fulfillment,', 'you', 'will'): ['never'],
#  ('you', 'will', 'never'): ['be', 'be'],
#  ('will', 'never', 'be'): ['fulfilled.', 'happy'],
#  ('never', 'be', 'fulfilled.'): ['If'],
#  ('be', 'fulfilled.', 'If'): ['your'],
#  ('fulfilled.', 'If', 'your'): ['happiness'],
#  ('If', 'your', 'happiness'): ['depends'],
#  ('your', 'happiness', 'depends'): ['on'],
#  ('happiness', 'depends', 'on'): ['money,'],
#  ('depends', 'on', 'money,'): ['you'],
#  ('on', 'money,', 'you'): ['will'],
#  ('money,', 'you', 'will'): ['never'],
#  ('never', 'be', 'happy'): ['with'],
#  ('be', 'happy', 'with'): ['yourself.'],
#  ('happy', 'with', 'yourself.'): ['Be'],
#  ('with', 'yourself.', 'Be'): ['content'],
#  ('yourself.', 'Be', 'content'): ['with'],
#  ('Be', 'content', 'with'): ['what'],
#  ('content', 'with', 'what'): ['you'],
#  ('with', 'what', 'you'): ['have;', 'have.', 'see.'],
#  ('what', 'you', 'have;'): ['rejoice'],
#  ('you', 'have;', 'rejoice'): ['in'],
#  ('have;', 'rejoice', 'in'): ['the'],
#  ('rejoice', 'in', 'the'): ['way'],
#  ('in', 'the', 'way'): ['things'],
#  ('the', 'way', 'things'): ['are.'],
#  ('way', 'things', 'are.'): ['When'],
#  ('things', 'are.', 'When'): ['you'],
#  ('are.', 'When', 'you'): ['realize'],
#  ('When', 'you', 'realize'): ['there'],
#  ('you', 'realize', 'there'): ['is'],
#  ('realize', 'there', 'is'): ['nothing'],
#  ('there', 'is', 'nothing'): ['lacking,'],
#  ('is', 'nothing', 'lacking,'): ['the'],
#  ('nothing', 'lacking,', 'the'): ['world'],
#  ('lacking,', 'the', 'world'): ['belongs'],
#  ('the', 'world', 'belongs'): ['to'],
#  ('world', 'belongs', 'to'): ['you.'],
#  ('belongs', 'to', 'you.'): ['Everything'],
#  ('to', 'you.', 'Everything'): ['is'],
#  ('you.', 'Everything', 'is'): ['a', 'a'],
#  ('Everything', 'is', 'a'): ['gift', 'gift'],
#  ('is', 'a', 'gift'): ['of', 'of'],
#  ('a', 'gift', 'of'): ['the', 'the'],
#  ('gift', 'of', 'the'): ['universe', 'universe'],
#  ('of', 'the', 'universe'): ['—even', '-'],
#  ('the', 'universe', '—even'): ['joy,'],
#  ('universe', '—even', 'joy,'): ['anger,'],
#  ('—even', 'joy,', 'anger,'): ['jealously,'],
#  ('joy,', 'anger,', 'jealously,'): ['frustration,', 'frustration,'],
#  ('anger,', 'jealously,', 'frustration,'): ['or', 'or'],
#  ('jealously,', 'frustration,', 'or'): ['separateness.', 'separateness.'],
#  ('frustration,', 'or', 'separateness.'): ['Everything', 'Everything'],
#  ('or', 'separateness.', 'Everything'): ['is', 'is'],
#  ('separateness.', 'Everything', 'is'): ['perfect', 'perfect'],
#  ('Everything', 'is', 'perfect'): ['either', 'either'],
#  ('is', 'perfect', 'either'): ['for', 'for'],
#  ('perfect', 'either', 'for'): ['our', 'our'],
#  ('either', 'for', 'our'): ['growth', 'growth'],
#  ('for', 'our', 'growth'): ['or', 'or'],
#  ('our', 'growth', 'or'): ['our', 'our'],
#  ('growth', 'or', 'our'): ['enjoyment.', 'enjoyment.'],
#  ('or', 'our', 'enjoyment.'): ['There', 'We'],
#  ('our', 'enjoyment.', 'There'): ['is'],
#  ('enjoyment.', 'There', 'is'): ['no'],
#  ('There', 'is', 'no'): ['such', 'stress'],
#  ('is', 'no', 'such'): ['thing'],
#  ('no', 'such', 'thing'): ['as'],
#  ('such', 'thing', 'as'): ['a'],
#  ('thing', 'as', 'a'): ['problem'],
#  ('as', 'a', 'problem'): ['without'],
#  ('a', 'problem', 'without'): ['a'],
#  ('problem', 'without', 'a'): ['gift'],
#  ('without', 'a', 'gift'): ['for'],
#  ('a', 'gift', 'for'): ['you'],
#  ('gift', 'for', 'you'): ['in'],
#  ('for', 'you', 'in'): ['its'],
#  ('you', 'in', 'its'): ['hands.'],
#  ('in', 'its', 'hands.'): ['You'],
#  ('its', 'hands.', 'You'): ['seek'],
#  ('hands.', 'You', 'seek'): ['problems'],
#  ('You', 'seek', 'problems'): ['because'],
#  ('seek', 'problems', 'because'): ['you'],
#  ('problems', 'because', 'you'): ['need'],
#  ('because', 'you', 'need'): ['their'],
#  ('you', 'need', 'their'): ['gifts.'],
#  ('need', 'their', 'gifts.'): ['If'],
#  ('their', 'gifts.', 'If'): ['you'],
#  ('gifts.', 'If', 'you'): ['want'],
#  ('If', 'you', 'want'): ['to', 'others', 'to'],
#  ('you', 'want', 'to'): ['be', 'be'],
#  ('want', 'to', 'be'): ['happy,', 'happy,'],
#  ('to', 'be', 'happy,'): ['set', 'practice', 'practice'],
#  ('be', 'happy,', 'set'): ['a'],
#  ('happy,', 'set', 'a'): ['goal'],
#  ('set', 'a', 'goal'): ['that'],
#  ('a', 'goal', 'that'): ['commands'],
#  ('goal', 'that', 'commands'): ['your'],
#  ('that', 'commands', 'your'): ['thoughts,'],
#  ('commands', 'your', 'thoughts,'): ['liberates'],
#  ('your', 'thoughts,', 'liberates'): ['your'],
#  ('thoughts,', 'liberates', 'your'): ['energy,'],
#  ('liberates', 'your', 'energy,'): ['and'],
#  ('your', 'energy,', 'and'): ['inspires'],
#  ('energy,', 'and', 'inspires'): ['your'],
#  ('and', 'inspires', 'your'): ['hopes.'],
#  ('inspires', 'your', 'hopes.'): ['Tension'],
#  ('your', 'hopes.', 'Tension'): ['is'],
#  ('hopes.', 'Tension', 'is'): ['who'],
#  ('Tension', 'is', 'who'): ['you'],
#  ('is', 'who', 'you'): ['think', 'are.'],
#  ('who', 'you', 'think'): ['you'],
#  ('you', 'think', 'you'): ['should'],
#  ('think', 'you', 'should'): ['be,'],
#  ('you', 'should', 'be,'): ['relaxation'],
#  ('should', 'be,', 'relaxation'): ['is'],
#  ('be,', 'relaxation', 'is'): ['who'],
#  ('relaxation', 'is', 'who'): ['you'],
#  ('who', 'you', 'are.'): ['I'],
#  ('you', 'are.', 'I'): ['believe'],
#  ('are.', 'I', 'believe'): ['the'],
#  ('I', 'believe', 'the'): ['recipe'],
#  ('believe', 'the', 'recipe'): ['for'],
#  ('the', 'recipe', 'for'): ['happiness'],
#  ('recipe', 'for', 'happiness'): ['to'],
#  ('for', 'happiness', 'to'): ['be'],
#  ('happiness', 'to', 'be'): ['just'],
#  ('to', 'be', 'just'): ['enough'],
#  ('be', 'just', 'enough'): ['money'],
#  ('just', 'enough', 'money'): ['to'],
#  ('enough', 'money', 'to'): ['pay'],
#  ('money', 'to', 'pay'): ['the'],
#  ('to', 'pay', 'the'): ['monthly'],
#  ('pay', 'the', 'monthly'): ['bills'],
#  ('the', 'monthly', 'bills'): ['you'],
#  ('monthly', 'bills', 'you'): ['acquire,'],
#  ('bills', 'you', 'acquire,'): ['a'],
#  ('you', 'acquire,', 'a'): ['little'],
#  ('acquire,', 'a', 'little'): ['surplus'],
#  ('a', 'little', 'surplus'): ['to'],
#  ('little', 'surplus', 'to'): ['give'],
#  ('surplus', 'to', 'give'): ['you'],
#  ('to', 'give', 'you'): ['confidence,'],
#  ('give', 'you', 'confidence,'): ['a'],
#  ('you', 'confidence,', 'a'): ['little'],
#  ('confidence,', 'a', 'little'): ['too'],
#  ('a', 'little', 'too'): ['much'],
#  ('little', 'too', 'much'): ['work'],
#  ('too', 'much', 'work'): ['each'],
#  ('much', 'work', 'each'): ['day,'],
#  ('work', 'each', 'day,'): ['enthusiasm'],
#  ('each', 'day,', 'enthusiasm'): ['for'],
#  ('day,', 'enthusiasm', 'for'): ['your'],
#  ('enthusiasm', 'for', 'your'): ['work,'],
#  ('for', 'your', 'work,'): ['a'],
#  ('your', 'work,', 'a'): ['substantial'],
#  ('work,', 'a', 'substantial'): ['share'],
#  ('a', 'substantial', 'share'): ['of'],
#  ('substantial', 'share', 'of'): ['good'],
#  ('share', 'of', 'good'): ['health,'],
#  ('of', 'good', 'health,'): ['a'],
#  ('good', 'health,', 'a'): ['couple'],
#  ('health,', 'a', 'couple'): ['of'],
#  ('a', 'couple', 'of'): ['real'],
#  ('couple', 'of', 'real'): ['friends'],
#  ('of', 'real', 'friends'): ['and'],
#  ('real', 'friends', 'and'): ['a'],
#  ('friends', 'and', 'a'): ['wife'],
#  ('and', 'a', 'wife'): ['and'],
#  ('a', 'wife', 'and'): ['children'],
#  ('wife', 'and', 'children'): ['to'],
#  ('and', 'children', 'to'): ['share'],
#  ('children', 'to', 'share'): ['life’s'],
#  ('to', 'share', 'life’s'): ['beauty'],
#  ('share', 'life’s', 'beauty'): ['with'],
#  ('life’s', 'beauty', 'with'): ['you.'],
#  ('beauty', 'with', 'you.'): ['For'],
#  ('with', 'you.', 'For'): ['me'],
#  ('you.', 'For', 'me'): ['it'],
#  ('For', 'me', 'it'): ['is'],
#  ('me', 'it', 'is'): ['sufficient'],
#  ('it', 'is', 'sufficient'): ['to'],
#  ('is', 'sufficient', 'to'): ['have'],
#  ('sufficient', 'to', 'have'): ['a'],
#  ('to', 'have', 'a'): ['corner'],
#  ('have', 'a', 'corner'): ['by'],
#  ('a', 'corner', 'by'): ['my'],
#  ('corner', 'by', 'my'): ['hearth,'],
#  ('by', 'my', 'hearth,'): ['a'],
#  ('my', 'hearth,', 'a'): ['book'],
#  ('hearth,', 'a', 'book'): ['and'],
#  ('a', 'book', 'and'): ['a'],
#  ('book', 'and', 'a'): ['friend,'],
#  ('and', 'a', 'friend,'): ['and'],
#  ('a', 'friend,', 'and'): ['a'],
#  ('friend,', 'and', 'a'): ['nap'],
#  ('and', 'a', 'nap'): ['undisturbed'],
#  ('a', 'nap', 'undisturbed'): ['by'],
#  ('nap', 'undisturbed', 'by'): ['creditors'],
#  ('undisturbed', 'by', 'creditors'): ['or'],
#  ('by', 'creditors', 'or'): ['grief.'],
#  ('creditors', 'or', 'grief.'): ['You'],
#  ('or', 'grief.', 'You'): ['cannot'],
#  ('grief.', 'You', 'cannot'): ['judge'],
#  ('You', 'cannot', 'judge'): ['what'],
#  ('cannot', 'judge', 'what'): ['should', 'should'],
#  ('judge', 'what', 'should'): ['bring', 'bring'],
#  ('what', 'should', 'bring'): ['others', 'you'],
#  ('should', 'bring', 'others'): ['joy,'],
#  ('bring', 'others', 'joy,'): ['and'],
#  ('others', 'joy,', 'and'): ['others'],
#  ('joy,', 'and', 'others'): ['cannot'],
#  ('and', 'others', 'cannot'): ['judge'],
#  ('others', 'cannot', 'judge'): ['what'],
#  ('should', 'bring', 'you'): ['joy.'],
#  ('bring', 'you', 'joy.'): ['The'],
#  ('you', 'joy.', 'The'): ['art'],
#  ('joy.', 'The', 'art'): ['of'],
#  ('The', 'art', 'of'): ['living'],
#  ('art', 'of', 'living'): ['lies'],
#  ('of', 'living', 'lies'): ['less'],
#  ('living', 'lies', 'less'): ['in'],
#  ('lies', 'less', 'in'): ['eliminating'],
#  ('less', 'in', 'eliminating'): ['our'],
#  ('in', 'eliminating', 'our'): ['troubles'],
#  ('eliminating', 'our', 'troubles'): ['than'],
#  ('our', 'troubles', 'than'): ['growing'],
#  ('troubles', 'than', 'growing'): ['with'],
#  ('than', 'growing', 'with'): ['them.'],
#  ('growing', 'with', 'them.'): ['Be'],
#  ('with', 'them.', 'Be'): ['happy'],
#  ('them.', 'Be', 'happy'): ['with'],
#  ('Be', 'happy', 'with'): ['what'],
#  ('happy', 'with', 'what'): ['you'],
#  ('what', 'you', 'have.'): ['Be', 'True'],
#  ('you', 'have.', 'Be'): ['excited'],
#  ('have.', 'Be', 'excited'): ['about'],
#  ('Be', 'excited', 'about'): ['what'],
#  ('excited', 'about', 'what'): ['you'],
#  ('about', 'what', 'you'): ['want.'],
#  ('what', 'you', 'want.'): ['Our', 'It', 'Happiness'],
#  ('you', 'want.', 'Our'): ['capacity'],
#  ('want.', 'Our', 'capacity'): ['to'],
#  ('Our', 'capacity', 'to'): ['draw'],
#  ('capacity', 'to', 'draw'): ['happiness'],
#  ('to', 'draw', 'happiness'): ['from'],
#  ('draw', 'happiness', 'from'): ['aesthetic'],
#  ('happiness', 'from', 'aesthetic'): ['objects'],
#  ('from', 'aesthetic', 'objects'): ['or'],
#  ('aesthetic', 'objects', 'or'): ['material'],
#  ('objects', 'or', 'material'): ['goods'],
#  ('or', 'material', 'goods'): ['in'],
#  ('material', 'goods', 'in'): ['fact'],
#  ('goods', 'in', 'fact'): ['seems'],
#  ('in', 'fact', 'seems'): ['critically'],
#  ('fact', 'seems', 'critically'): ['dependent'],
#  ('seems', 'critically', 'dependent'): ['on'],
#  ('critically', 'dependent', 'on'): ['our'],
#  ('dependent', 'on', 'our'): ['first'],
#  ('on', 'our', 'first'): ['satisfying'],
#  ('our', 'first', 'satisfying'): ['a'],
#  ('first', 'satisfying', 'a'): ['more'],
#  ('satisfying', 'a', 'more'): ['important'],
#  ('a', 'more', 'important'): ['range'],
#  ('more', 'important', 'range'): ['of'],
#  ('important', 'range', 'of'): ['emotional'],
#  ('range', 'of', 'emotional'): ['or'],
#  ('of', 'emotional', 'or'): ['psychological'],
#  ('emotional', 'or', 'psychological'): ['needs,'],
#  ('or', 'psychological', 'needs,'): ['among'],
#  ('psychological', 'needs,', 'among'): ['them'],
#  ('needs,', 'among', 'them'): ['the'],
#  ('among', 'them', 'the'): ['need'],
#  ('them', 'the', 'need'): ['for'],
#  ('the', 'need', 'for'): ['understanding,'],
#  ('need', 'for', 'understanding,'): ['for'],
#  ('for', 'understanding,', 'for'): ['love,'],
#  ('understanding,', 'for', 'love,'): ['expression'],
#  ('for', 'love,', 'expression'): ['and'],
#  ('love,', 'expression', 'and'): ['respect.'],
#  ('expression', 'and', 'respect.'): ['If'],
#  ('and', 'respect.', 'If'): ['you'],
#  ('respect.', 'If', 'you'): ['start'],
#  ('If', 'you', 'start'): ['to'],
#  ('you', 'start', 'to'): ['think'],
#  ('start', 'to', 'think'): ['the'],
#  ('to', 'think', 'the'): ['problem'],
#  ('think', 'the', 'problem'): ['is'],
#  ('the', 'problem', 'is'): ['‘out'],
#  ('problem', 'is', '‘out'): ['there,’'],
#  ('is', '‘out', 'there,’'): ['stop'],
#  ('‘out', 'there,’', 'stop'): ['yourself.'],
#  ('there,’', 'stop', 'yourself.'): ['That'],
#  ('stop', 'yourself.', 'That'): ['thought'],
#  ('yourself.', 'That', 'thought'): ['is'],
#  ('That', 'thought', 'is'): ['the'],
#  ('thought', 'is', 'the'): ['problem.'],
#  ('is', 'the', 'problem.'): ['Happiness'],
#  ('the', 'problem.', 'Happiness'): ['cannot'],
#  ('problem.', 'Happiness', 'cannot'): ['be'],
#  ('Happiness', 'cannot', 'be'): ['traveled'],
#  ('cannot', 'be', 'traveled'): ['to,'],
#  ('be', 'traveled', 'to,'): ['owned,'],
#  ('traveled', 'to,', 'owned,'): ['earned,'],
#  ('to,', 'owned,', 'earned,'): ['worn'],
#  ('owned,', 'earned,', 'worn'): ['or'],
#  ('earned,', 'worn', 'or'): ['consumed.'],
#  ('worn', 'or', 'consumed.'): ['Happiness'],
#  ('or', 'consumed.', 'Happiness'): ['is'],
#  ('consumed.', 'Happiness', 'is'): ['the'],
#  ('Happiness', 'is', 'the'): ['spiritual', 'meaning', 'experience'],
#  ('is', 'the', 'spiritual'): ['experience'],
#  ('the', 'spiritual', 'experience'): ['of'],
#  ('spiritual', 'experience', 'of'): ['living'],
#  ('experience', 'of', 'living'): ['every'],
#  ('of', 'living', 'every'): ['minute'],
#  ('living', 'every', 'minute'): ['with'],
#  ('every', 'minute', 'with'): ['love,'],
#  ('minute', 'with', 'love,'): ['grace,'],
#  ('with', 'love,', 'grace,'): ['and'],
#  ('love,', 'grace,', 'and'): ['gratitude.'],
#  ('grace,', 'and', 'gratitude.'): ['Happiness'],
#  ('and', 'gratitude.', 'Happiness'): ['is'],
#  ('gratitude.', 'Happiness', 'is'): ['not'],
#  ('Happiness', 'is', 'not'): ['a', 'having'],
#  ('is', 'not', 'a'): ['station'],
#  ('not', 'a', 'station'): ['you'],
#  ('a', 'station', 'you'): ['arrive'],
#  ('station', 'you', 'arrive'): ['at,'],
#  ('you', 'arrive', 'at,'): ['but'],
#  ('arrive', 'at,', 'but'): ['a'],
#  ('at,', 'but', 'a'): ['manner'],
#  ('but', 'a', 'manner'): ['of'],
#  ('a', 'manner', 'of'): ['traveling.'],
#  ('manner', 'of', 'traveling.'): ['Happiness'],
#  ('of', 'traveling.', 'Happiness'): ['is'],
#  ('traveling.', 'Happiness', 'is'): ['the'],
#  ('is', 'the', 'meaning'): ['and'],
#  ('the', 'meaning', 'and'): ['the'],
#  ('meaning', 'and', 'the'): ['purpose'],
#  ('and', 'the', 'purpose'): ['of'],
#  ('the', 'purpose', 'of'): ['life,'],
#  ('purpose', 'of', 'life,'): ['the'],
#  ('of', 'life,', 'the'): ['whole'],
#  ('life,', 'the', 'whole'): ['aim'],
#  ('the', 'whole', 'aim'): ['and'],
#  ('whole', 'aim', 'and'): ['end'],
#  ('aim', 'and', 'end'): ['of'],
#  ('and', 'end', 'of'): ['human'],
#  ('end', 'of', 'human'): ['existence.'],
#  ('of', 'human', 'existence.'): ['Security'],
#  ('human', 'existence.', 'Security'): ['is'],
#  ('existence.', 'Security', 'is'): ['when'],
#  ('Security', 'is', 'when'): ['everything'],
#  ('is', 'when', 'everything'): ['is'],
#  ('when', 'everything', 'is'): ['settled,'],
#  ('everything', 'is', 'settled,'): ['when'],
#  ('is', 'settled,', 'when'): ['nothing'],
#  ('settled,', 'when', 'nothing'): ['can'],
#  ('when', 'nothing', 'can'): ['happen'],
#  ('nothing', 'can', 'happen'): ['to'],
#  ('can', 'happen', 'to'): ['you;'],
#  ('happen', 'to', 'you;'): ['security'],
#  ('to', 'you;', 'security'): ['is'],
#  ('you;', 'security', 'is'): ['the'],
#  ('security', 'is', 'the'): ['denial'],
#  ('is', 'the', 'denial'): ['of'],
#  ('the', 'denial', 'of'): ['life.'],
#  ('denial', 'of', 'life.'): ['Focus'],
#  ('of', 'life.', 'Focus'): ['on'],
#  ('life.', 'Focus', 'on'): ['the'],
#  ('Focus', 'on', 'the'): ['journey,'],
#  ('on', 'the', 'journey,'): ['not'],
#  ('the', 'journey,', 'not'): ['the'],
#  ('journey,', 'not', 'the'): ['destination.'],
#  ('not', 'the', 'destination.'): ['Joy'],
#  ('the', 'destination.', 'Joy'): ['is'],
#  ('destination.', 'Joy', 'is'): ['found'],
#  ('Joy', 'is', 'found'): ['not'],
#  ('is', 'found', 'not'): ['in'],
#  ('found', 'not', 'in'): ['finishing'],
#  ('not', 'in', 'finishing'): ['an'],
#  ('in', 'finishing', 'an'): ['activity'],
#  ('finishing', 'an', 'activity'): ['but'],
#  ('an', 'activity', 'but'): ['in'],
#  ('activity', 'but', 'in'): ['doing'],
#  ('but', 'in', 'doing'): ['it.'],
#  ('in', 'doing', 'it.'): ['Thousands'],
#  ('doing', 'it.', 'Thousands'): ['of'],
#  ('it.', 'Thousands', 'of'): ['candles'],
#  ('Thousands', 'of', 'candles'): ['can'],
#  ('of', 'candles', 'can'): ['be'],
#  ('candles', 'can', 'be'): ['lit'],
#  ('can', 'be', 'lit'): ['from'],
#  ('be', 'lit', 'from'): ['a'],
#  ('lit', 'from', 'a'): ['single'],
#  ('from', 'a', 'single'): ['candle,'],
#  ('a', 'single', 'candle,'): ['and'],
#  ('single', 'candle,', 'and'): ['the'],
#  ('candle,', 'and', 'the'): ['life'],
#  ('and', 'the', 'life'): ['of'],
#  ('the', 'life', 'of'): ['the'],
#  ('life', 'of', 'the'): ['candle'],
#  ('of', 'the', 'candle'): ['will'],
#  ('the', 'candle', 'will'): ['not'],
#  ('candle', 'will', 'not'): ['be'],
#  ('will', 'not', 'be'): ['shortened.'],
#  ('not', 'be', 'shortened.'): ['Happiness'],
#  ('be', 'shortened.', 'Happiness'): ['never'],
#  ('shortened.', 'Happiness', 'never'): ['decreases'],
#  ('Happiness', 'never', 'decreases'): ['by'],
#  ('never', 'decreases', 'by'): ['being'],
#  ('decreases', 'by', 'being'): ['shared.'],
#  ('by', 'being', 'shared.'): ['The'],
#  ('being', 'shared.', 'The'): ['best'],
#  ('shared.', 'The', 'best'): ['remedy'],
#  ('The', 'best', 'remedy'): ['for'],
#  ('best', 'remedy', 'for'): ['those'],
#  ('remedy', 'for', 'those'): ['who'],
#  ('for', 'those', 'who'): ['are'],
#  ('those', 'who', 'are'): ['afraid,'],
#  ('who', 'are', 'afraid,'): ['lonely'],
#  ('are', 'afraid,', 'lonely'): ['or'],
#  ('afraid,', 'lonely', 'or'): ['unhappy'],
#  ('lonely', 'or', 'unhappy'): ['is'],
#  ('or', 'unhappy', 'is'): ['to'],
#  ('unhappy', 'is', 'to'): ['go'],
#  ('is', 'to', 'go'): ['outside,'],
#  ('to', 'go', 'outside,'): ['somewhere'],
#  ('go', 'outside,', 'somewhere'): ['where'],
#  ('outside,', 'somewhere', 'where'): ['they'],
#  ('somewhere', 'where', 'they'): ['can'],
#  ('where', 'they', 'can'): ['be'],
#  ('they', 'can', 'be'): ['quiet,'],
#  ('can', 'be', 'quiet,'): ['alone'],
#  ('be', 'quiet,', 'alone'): ['with'],
#  ('quiet,', 'alone', 'with'): ['the'],
#  ('alone', 'with', 'the'): ['heavens,'],
#  ('with', 'the', 'heavens,'): ['nature'],
#  ('the', 'heavens,', 'nature'): ['and'],
#  ('heavens,', 'nature', 'and'): ['God.'],
#  ('nature', 'and', 'God.'): ['As'],
#  ('and', 'God.', 'As'): ['long'],
#  ('God.', 'As', 'long'): ['as'],
#  ('As', 'long', 'as'): ['this'],
#  ('long', 'as', 'this'): ['exists,'],
#  ('as', 'this', 'exists,'): ['and'],
#  ('this', 'exists,', 'and'): ['it'],
#  ('exists,', 'and', 'it'): ['certainly'],
#  ('and', 'it', 'certainly'): ['always'],
#  ('it', 'certainly', 'always'): ['will,'],
#  ('certainly', 'always', 'will,'): ['then'],
#  ('always', 'will,', 'then'): ['there'],
#  ('will,', 'then', 'there'): ['will'],
#  ('then', 'there', 'will'): ['be'],
#  ('there', 'will', 'be'): ['comfort', 'dire'],
#  ('will', 'be', 'comfort'): ['for'],
#  ('be', 'comfort', 'for'): ['every'],
#  ('comfort', 'for', 'every'): ['sorrow,'],
#  ('for', 'every', 'sorrow,'): ['whatever'],
#  ('every', 'sorrow,', 'whatever'): ['the'],
#  ('sorrow,', 'whatever', 'the'): ['circumstances'],
#  ('whatever', 'the', 'circumstances'): ['may'],
#  ('the', 'circumstances', 'may'): ['be.'],
#  ('circumstances', 'may', 'be.'): ['In'],
#  ('may', 'be.', 'In'): ['our'],
#  ('be.', 'In', 'our'): ['lives,'],
#  ('In', 'our', 'lives,'): ['change'],
#  ('our', 'lives,', 'change'): ['is'],
#  ('lives,', 'change', 'is'): ['unavoidable,'],
#  ('change', 'is', 'unavoidable,'): ['loss'],
#  ('is', 'unavoidable,', 'loss'): ['is'],
#  ('unavoidable,', 'loss', 'is'): ['unavoidable.'],
#  ('loss', 'is', 'unavoidable.'): ['In'],
#  ('is', 'unavoidable.', 'In'): ['the'],
#  ('unavoidable.', 'In', 'the'): ['adaptability'],
#  ('In', 'the', 'adaptability'): ['and'],
#  ('the', 'adaptability', 'and'): ['ease'],
#  ('adaptability', 'and', 'ease'): ['with'],
#  ('and', 'ease', 'with'): ['which'],
#  ('ease', 'with', 'which'): ['we'],
#  ('with', 'which', 'we'): ['experience'],
#  ('which', 'we', 'experience'): ['change,'],
#  ('we', 'experience', 'change,'): ['lies'],
#  ('experience', 'change,', 'lies'): ['our'],
#  ('change,', 'lies', 'our'): ['happiness'],
#  ('lies', 'our', 'happiness'): ['and'],
#  ('our', 'happiness', 'and'): ['freedom.'],
#  ('happiness', 'and', 'freedom.'): ['Live'],
#  ('and', 'freedom.', 'Live'): ['with'],
#  ('freedom.', 'Live', 'with'): ['intention.'],
#  ('Live', 'with', 'intention.'): ['Walk'],
#  ('with', 'intention.', 'Walk'): ['to'],
#  ('intention.', 'Walk', 'to'): ['the'],
#  ('Walk', 'to', 'the'): ['edge.'],
#  ('to', 'the', 'edge.'): ['Listen'],
#  ('the', 'edge.', 'Listen'): ['hard.'],
#  ('edge.', 'Listen', 'hard.'): ['Practice'],
#  ('Listen', 'hard.', 'Practice'): ['wellness.'],
#  ('hard.', 'Practice', 'wellness.'): ['Play'],
#  ('Practice', 'wellness.', 'Play'): ['with'],
#  ('wellness.', 'Play', 'with'): ['abandon.'],
#  ('Play', 'with', 'abandon.'): ['Laugh.'],
#  ('with', 'abandon.', 'Laugh.'): ['Choose'],
#  ('abandon.', 'Laugh.', 'Choose'): ['with'],
#  ('Laugh.', 'Choose', 'with'): ['no'],
#  ('Choose', 'with', 'no'): ['regret.'],
#  ('with', 'no', 'regret.'): ['Do'],
#  ('no', 'regret.', 'Do'): ['what'],
#  ('regret.', 'Do', 'what'): ['you'],
#  ('Do', 'what', 'you'): ['love.', 'have'],
#  ('what', 'you', 'love.'): ['Live'],
#  ('you', 'love.', 'Live'): ['as'],
#  ('love.', 'Live', 'as'): ['if'],
#  ('Live', 'as', 'if'): ['this'],
#  ('as', 'if', 'this'): ['is'],
#  ('if', 'this', 'is'): ['all'],
#  ('this', 'is', 'all'): ['there'],
#  ('is', 'all', 'there'): ['is.'],
#  ('all', 'there', 'is.'): ['You'],
#  ('there', 'is.', 'You'): ['never'],
#  ('is.', 'You', 'never'): ['regret'],
#  ('You', 'never', 'regret'): ['being'],
#  ('never', 'regret', 'being'): ['kind.'],
#  ('regret', 'being', 'kind.'): ['They'],
#  ('being', 'kind.', 'They'): ['who'],
#  ('kind.', 'They', 'who'): ['can'],
#  ('They', 'who', 'can'): ['give'],
#  ('who', 'can', 'give'): ['up', 'without'],
#  ('can', 'give', 'up'): ['essential'],
#  ('give', 'up', 'essential'): ['liberty'],
#  ('up', 'essential', 'liberty'): ['to'],
#  ('essential', 'liberty', 'to'): ['obtain'],
#  ('liberty', 'to', 'obtain'): ['a'],
#  ('to', 'obtain', 'a'): ['little'],
#  ('obtain', 'a', 'little'): ['temporary'],
#  ('a', 'little', 'temporary'): ['safety,'],
#  ('little', 'temporary', 'safety,'): ['deserve'],
#  ('temporary', 'safety,', 'deserve'): ['neither'],
#  ('safety,', 'deserve', 'neither'): ['liberty'],
#  ('deserve', 'neither', 'liberty'): ['nor'],
#  ('neither', 'liberty', 'nor'): ['safety.'],
#  ('liberty', 'nor', 'safety.'): ['Forgiveness'],
#  ('nor', 'safety.', 'Forgiveness'): ['does'],
#  ('safety.', 'Forgiveness', 'does'): ['not'],
#  ('Forgiveness', 'does', 'not'): ['change'],
#  ('does', 'not', 'change'): ['the'],
#  ('not', 'change', 'the'): ['past,'],
#  ('change', 'the', 'past,'): ['but'],
#  ('the', 'past,', 'but'): ['it'],
#  ('past,', 'but', 'it'): ['does'],
#  ('but', 'it', 'does'): ['enlarge'],
#  ('it', 'does', 'enlarge'): ['the'],
#  ('does', 'enlarge', 'the'): ['future.'],
#  ('enlarge', 'the', 'future.'): ['The'],
#  ('the', 'future.', 'The'): ['secret'],
#  ('future.', 'The', 'secret'): ['of'],
#  ('The', 'secret', 'of'): ['health'],
#  ('secret', 'of', 'health'): ['for'],
#  ('of', 'health', 'for'): ['both'],
#  ('health', 'for', 'both'): ['mind'],
#  ('for', 'both', 'mind'): ['and'],
#  ('both', 'mind', 'and'): ['body'],
#  ('mind', 'and', 'body'): ['is'],
#  ('and', 'body', 'is'): ['not'],
#  ('body', 'is', 'not'): ['to'],
#  ('is', 'not', 'to'): ['mourn'],
#  ('not', 'to', 'mourn'): ['for'],
#  ('to', 'mourn', 'for'): ['the'],
#  ('mourn', 'for', 'the'): ['past,'],
#  ('for', 'the', 'past,'): ['worry'],
#  ('the', 'past,', 'worry'): ['about'],
#  ('past,', 'worry', 'about'): ['the'],
#  ('worry', 'about', 'the'): ['future,'],
#  ('about', 'the', 'future,'): ['or'],
#  ('the', 'future,', 'or'): ['anticipate'],
#  ('future,', 'or', 'anticipate'): ['troubles,'],
#  ('or', 'anticipate', 'troubles,'): ['but'],
#  ('anticipate', 'troubles,', 'but'): ['to'],
#  ('troubles,', 'but', 'to'): ['live'],
#  ('but', 'to', 'live'): ['in'],
#  ('to', 'live', 'in'): ['the'],
#  ('live', 'in', 'the'): ['present'],
#  ('in', 'the', 'present'): ['moment'],
#  ('the', 'present', 'moment'): ['wisely'],
#  ('present', 'moment', 'wisely'): ['and'],
#  ('moment', 'wisely', 'and'): ['earnestly.'],
#  ('wisely', 'and', 'earnestly.'): ['True'],
#  ('and', 'earnestly.', 'True'): ['happiness'],
#  ('earnestly.', 'True', 'happiness'): ['is'],
#  ('True', 'happiness', 'is'): ['not'],
#  ('happiness', 'is', 'not'): ['attained'],
#  ('is', 'not', 'attained'): ['through'],
#  ('not', 'attained', 'through'): ['self-gratification,'],
#  ('attained', 'through', 'self-gratification,'): ['but'],
#  ('through', 'self-gratification,', 'but'): ['through'],
#  ('self-gratification,', 'but', 'through'): ['fidelity'],
#  ('but', 'through', 'fidelity'): ['to'],
#  ('through', 'fidelity', 'to'): ['a'],
#  ('fidelity', 'to', 'a'): ['worthy'],
#  ('to', 'a', 'worthy'): ['purpose.'],
#  ('a', 'worthy', 'purpose.'): ['Most'],
#  ('worthy', 'purpose.', 'Most'): ['of'],
#  ('purpose.', 'Most', 'of'): ['us'],
#  ('Most', 'of', 'us'): ['miss'],
#  ('of', 'us', 'miss'): ['out'],
#  ('us', 'miss', 'out'): ['on'],
#  ('miss', 'out', 'on'): ['life’s'],
#  ('out', 'on', 'life’s'): ['big'],
#  ('on', 'life’s', 'big'): ['prizes.'],
#  ('life’s', 'big', 'prizes.'): ['The'],
#  ('big', 'prizes.', 'The'): ['Pulitzer.'],
#  ('prizes.', 'The', 'Pulitzer.'): ['The'],
#  ('The', 'Pulitzer.', 'The'): ['Nobel.'],
#  ('Pulitzer.', 'The', 'Nobel.'): ['Oscars.'],
#  ('The', 'Nobel.', 'Oscars.'): ['The'],
#  ('Nobel.', 'Oscars.', 'The'): ['World'],
#  ('Oscars.', 'The', 'World'): ['Cup.'],
#  ('The', 'World', 'Cup.'): ['But'],
#  ('World', 'Cup.', 'But'): ['we’re'],
#  ('Cup.', 'But', 'we’re'): ['all'],
#  ('But', 'we’re', 'all'): ['eligible'],
#  ('we’re', 'all', 'eligible'): ['for'],
#  ('all', 'eligible', 'for'): ['life’s'],
#  ('eligible', 'for', 'life’s'): ['smaller'],
#  ('for', 'life’s', 'smaller'): ['prizes...'],
#  ('life’s', 'smaller', 'prizes...'): ['A'],
#  ('smaller', 'prizes...', 'A'): ['pat'],
#  ('prizes...', 'A', 'pat'): ['on'],
#  ('A', 'pat', 'on'): ['the'],
#  ('pat', 'on', 'the'): ['back.'],
#  ('on', 'the', 'back.'): ['A'],
#  ('the', 'back.', 'A'): ['kiss'],
#  ('back.', 'A', 'kiss'): ['behind'],
#  ('A', 'kiss', 'behind'): ['the'],
#  ('kiss', 'behind', 'the'): ['ear.'],
#  ('behind', 'the', 'ear.'): ['A'],
#  ('the', 'ear.', 'A'): ['four-pound'],
#  ('ear.', 'A', 'four-pound'): ['bass.'],
#  ('A', 'four-pound', 'bass.'): ['A'],
#  ('four-pound', 'bass.', 'A'): ['full'],
#  ('bass.', 'A', 'full'): ['moon.'],
#  ('A', 'full', 'moon.'): ['An'],
#  ('full', 'moon.', 'An'): ['empty'],
#  ('moon.', 'An', 'empty'): ['parking'],
#  ('An', 'empty', 'parking'): ['space.'],
#  ('empty', 'parking', 'space.'): ['A'],
#  ('parking', 'space.', 'A'): ['crackling'],
#  ('space.', 'A', 'crackling'): ['fire.'],
#  ('A', 'crackling', 'fire.'): ['A'],
#  ('crackling', 'fire.', 'A'): ['great'],
#  ('fire.', 'A', 'great'): ['meal.'],
#  ('A', 'great', 'meal.'): ['A'],
#  ('great', 'meal.', 'A'): ['glorious'],
#  ('meal.', 'A', 'glorious'): ['sunset.'],
#  ('A', 'glorious', 'sunset.'): ['Hot'],
#  ('glorious', 'sunset.', 'Hot'): ['soup.'],
#  ('sunset.', 'Hot', 'soup.'): ['Cold'],
#  ('Hot', 'soup.', 'Cold'): ['beer.'],
#  ('soup.', 'Cold', 'beer.'): ['Money'],
#  ('Cold', 'beer.', 'Money'): ['is'],
#  ('beer.', 'Money', 'is'): ['neither'],
#  ('Money', 'is', 'neither'): ['my'],
#  ('is', 'neither', 'my'): ['god'],
#  ('neither', 'my', 'god'): ['nor'],
#  ('my', 'god', 'nor'): ['my'],
#  ('god', 'nor', 'my'): ['devil.'],
#  ('nor', 'my', 'devil.'): ['It'],
#  ('my', 'devil.', 'It'): ['is'],
#  ('devil.', 'It', 'is'): ['a'],
#  ('It', 'is', 'a'): ['form'],
#  ('is', 'a', 'form'): ['of'],
#  ('a', 'form', 'of'): ['energy'],
#  ('form', 'of', 'energy'): ['that'],
#  ('of', 'energy', 'that'): ['tends'],
#  ('energy', 'that', 'tends'): ['to'],
#  ('that', 'tends', 'to'): ['make'],
#  ('tends', 'to', 'make'): ['us'],
#  ('to', 'make', 'us'): ['more'],
#  ('make', 'us', 'more'): ['of'],
#  ('us', 'more', 'of'): ['who'],
#  ('more', 'of', 'who'): ['we'],
#  ('of', 'who', 'we'): ['already'],
#  ('who', 'we', 'already'): ['are,'],
#  ('we', 'already', 'are,'): ['whether'],
#  ('already', 'are,', 'whether'): ['it’s'],
#  ('are,', 'whether', 'it’s'): ['greedy'],
#  ('whether', 'it’s', 'greedy'): ['or'],
#  ('it’s', 'greedy', 'or'): ['loving.'],
#  ('greedy', 'or', 'loving.'): ['The'],
#  ('or', 'loving.', 'The'): ['need'],
#  ('loving.', 'The', 'need'): ['for'],
#  ('The', 'need', 'for'): ['forgiveness'],
#  ('need', 'for', 'forgiveness'): ['is'],
#  ('for', 'forgiveness', 'is'): ['an'],
#  ('forgiveness', 'is', 'an'): ['illusion.'],
#  ('is', 'an', 'illusion.'): ['There'],
#  ('an', 'illusion.', 'There'): ['is'],
#  ('illusion.', 'There', 'is'): ['nothing'],
#  ('There', 'is', 'nothing'): ['to', 'enlightening'],
#  ('is', 'nothing', 'to'): ['forgive.'],
#  ('nothing', 'to', 'forgive.'): ['Blessed'],
#  ('to', 'forgive.', 'Blessed'): ['are'],
#  ('forgive.', 'Blessed', 'are'): ['those'],
#  ('Blessed', 'are', 'those'): ['who'],
#  ('are', 'those', 'who'): ['can'],
#  ('those', 'who', 'can'): ['give'],
#  ('can', 'give', 'without'): ['remembering'],
#  ('give', 'without', 'remembering'): ['and'],
#  ('without', 'remembering', 'and'): ['take'],
#  ('remembering', 'and', 'take'): ['without'],
#  ('and', 'take', 'without'): ['forgetting.'],
#  ('take', 'without', 'forgetting.'): ['Reflect'],
#  ('without', 'forgetting.', 'Reflect'): ['upon'],
#  ('forgetting.', 'Reflect', 'upon'): ['you'],
#  ('Reflect', 'upon', 'you'): ['present'],
#  ('upon', 'you', 'present'): ['blessings,'],
#  ('you', 'present', 'blessings,'): ['of'],
#  ('present', 'blessings,', 'of'): ['which'],
#  ('blessings,', 'of', 'which'): ['every'],
#  ('of', 'which', 'every'): ['man'],
#  ('which', 'every', 'man'): ['has'],
#  ('every', 'man', 'has'): ['many'],
#  ('man', 'has', 'many'): ['-'],
#  ('has', 'many', '-'): ['not'],
#  ('many', '-', 'not'): ['on'],
#  ('-', 'not', 'on'): ['your'],
#  ('not', 'on', 'your'): ['past'],
#  ('on', 'your', 'past'): ['misfortunes,'],
#  ('your', 'past', 'misfortunes,'): ['of'],
#  ('past', 'misfortunes,', 'of'): ['which'],
#  ('misfortunes,', 'of', 'which'): ['all'],
#  ('of', 'which', 'all'): ['men'],
#  ('which', 'all', 'men'): ['have'],
#  ('all', 'men', 'have'): ['some.'],
#  ('men', 'have', 'some.'): ['Even'],
#  ('have', 'some.', 'Even'): ['a'],
#  ('some.', 'Even', 'a'): ['happy'],
#  ('Even', 'a', 'happy'): ['life'],
#  ('a', 'happy', 'life'): ['cannot'],
#  ('happy', 'life', 'cannot'): ['be'],
#  ('life', 'cannot', 'be'): ['without'],
#  ('cannot', 'be', 'without'): ['a'],
#  ('be', 'without', 'a'): ['measure'],
#  ('without', 'a', 'measure'): ['of'],
#  ('a', 'measure', 'of'): ['darkness,'],
#  ('measure', 'of', 'darkness,'): ['and'],
#  ('of', 'darkness,', 'and'): ['the'],
#  ('darkness,', 'and', 'the'): ['word'],
#  ('and', 'the', 'word'): ['happy'],
#  ('the', 'word', 'happy'): ['would'],
#  ('word', 'happy', 'would'): ['lose'],
#  ('happy', 'would', 'lose'): ['its'],
#  ('would', 'lose', 'its'): ['meaning'],
#  ('lose', 'its', 'meaning'): ['if'],
#  ('its', 'meaning', 'if'): ['it'],
#  ('meaning', 'if', 'it'): ['were'],
#  ('if', 'it', 'were'): ['not'],
#  ('it', 'were', 'not'): ['balanced'],
#  ('were', 'not', 'balanced'): ['by'],
#  ('not', 'balanced', 'by'): ['sadness.'],
#  ('balanced', 'by', 'sadness.'): ['It'],
#  ('by', 'sadness.', 'It'): ['is'],
#  ('sadness.', 'It', 'is'): ['far'],
#  ('It', 'is', 'far'): ['better'],
#  ('is', 'far', 'better'): ['to'],
#  ('far', 'better', 'to'): ['take'],
#  ('better', 'to', 'take'): ['things'],
#  ('to', 'take', 'things'): ['as'],
#  ('take', 'things', 'as'): ['they'],
#  ('things', 'as', 'they'): ['come'],
#  ('as', 'they', 'come'): ['along'],
#  ('they', 'come', 'along'): ['with'],
#  ('come', 'along', 'with'): ['patience'],
#  ('along', 'with', 'patience'): ['and'],
#  ('with', 'patience', 'and'): ['equanimity.'],
#  ('patience', 'and', 'equanimity.'): ['Much'],
#  ('and', 'equanimity.', 'Much'): ['of'],
#  ('equanimity.', 'Much', 'of'): ['the'],
#  ('Much', 'of', 'the'): ['stress'],
#  ('of', 'the', 'stress'): ['that'],
#  ('the', 'stress', 'that'): ['people'],
#  ('stress', 'that', 'people'): ['feel'],
#  ('that', 'people', 'feel'): ['doesn’t'],
#  ('people', 'feel', 'doesn’t'): ['come'],
#  ('feel', 'doesn’t', 'come'): ['from'],
#  ('doesn’t', 'come', 'from'): ['having'],
#  ('come', 'from', 'having'): ['too'],
#  ('from', 'having', 'too'): ['much'],
#  ('having', 'too', 'much'): ['to'],
#  ('too', 'much', 'to'): ['do.'],
#  ('much', 'to', 'do.'): ['It'],
#  ('to', 'do.', 'It'): ['comes'],
#  ('do.', 'It', 'comes'): ['from'],
#  ('It', 'comes', 'from'): ['not'],
#  ('comes', 'from', 'not'): ['finishing'],
#  ('from', 'not', 'finishing'): ['what'],
#  ('not', 'finishing', 'what'): ['they’ve'],
#  ('finishing', 'what', 'they’ve'): ['started.'],
#  ('what', 'they’ve', 'started.'): ['He'],
#  ('they’ve', 'started.', 'He'): ['who'],
#  ('started.', 'He', 'who'): ['lives'],
#  ('He', 'who', 'lives'): ['in'],
#  ('who', 'lives', 'in'): ['harmony'],
#  ('lives', 'in', 'harmony'): ['with', 'with'],
#  ('in', 'harmony', 'with'): ['himself', 'the'],
#  ('harmony', 'with', 'himself'): ['lives'],
#  ('with', 'himself', 'lives'): ['in'],
#  ('himself', 'lives', 'in'): ['harmony'],
#  ('harmony', 'with', 'the'): ['universe.'],
#  ('with', 'the', 'universe.'): ['If'],
#  ('the', 'universe.', 'If'): ['you'],
#  ('universe.', 'If', 'you'): ['want'],
#  ('you', 'want', 'others'): ['to'],
#  ('want', 'others', 'to'): ['be'],
#  ('others', 'to', 'be'): ['happy,'],
#  ('be', 'happy,', 'practice'): ['compassion.', 'compassion.'],
#  ('happy,', 'practice', 'compassion.'): ['If', 'All'],
#  ('practice', 'compassion.', 'If'): ['you'],
#  ('compassion.', 'If', 'you'): ['want'],
#  ('practice', 'compassion.', 'All'): ['the'],
#  ('compassion.', 'All', 'the'): ['world’s'],
#  ('All', 'the', 'world’s'): ['a'],
#  ('the', 'world’s', 'a'): ['stage,'],
#  ('world’s', 'a', 'stage,'): ['and'],
#  ('a', 'stage,', 'and'): ['the'],
#  ('stage,', 'and', 'the'): ['men'],
#  ('and', 'the', 'men'): ['and'],
#  ('the', 'men', 'and'): ['women'],
#  ('men', 'and', 'women'): ['merely'],
#  ('and', 'women', 'merely'): ['players.'],
#  ('women', 'merely', 'players.'): ['They'],
#  ('merely', 'players.', 'They'): ['have'],
#  ('players.', 'They', 'have'): ['their'],
#  ('They', 'have', 'their'): ['exits'],
#  ('have', 'their', 'exits'): ['and'],
#  ('their', 'exits', 'and'): ['their'],
#  ('exits', 'and', 'their'): ['entrances;'],
#  ('and', 'their', 'entrances;'): ['and'],
#  ('their', 'entrances;', 'and'): ['one'],
#  ('entrances;', 'and', 'one'): ['man'],
#  ('and', 'one', 'man'): ['in'],
#  ('one', 'man', 'in'): ['his'],
#  ('man', 'in', 'his'): ['time'],
#  ('in', 'his', 'time'): ['plays'],
#  ('his', 'time', 'plays'): ['many'],
#  ('time', 'plays', 'many'): ['parts.'],
#  ('plays', 'many', 'parts.'): ['Dream'],
#  ('many', 'parts.', 'Dream'): ['as'],
#  ('parts.', 'Dream', 'as'): ['if'],
#  ('Dream', 'as', 'if'): ['you’ll'],
#  ('as', 'if', 'you’ll'): ['live', 'die'],
#  ('if', 'you’ll', 'live'): ['forever,'],
#  ('you’ll', 'live', 'forever,'): ['live'],
#  ('live', 'forever,', 'live'): ['as'],
#  ('forever,', 'live', 'as'): ['if'],
#  ('live', 'as', 'if'): ['you’ll'],
#  ('if', 'you’ll', 'die'): ['today.'],
#  ('you’ll', 'die', 'today.'): ['When'],
#  ('die', 'today.', 'When'): ['one'],
#  ('today.', 'When', 'one'): ['door'],
#  ('When', 'one', 'door'): ['of'],
#  ('one', 'door', 'of'): ['happiness'],
#  ('door', 'of', 'happiness'): ['closes,'],
#  ('of', 'happiness', 'closes,'): ['another'],
#  ('happiness', 'closes,', 'another'): ['opens,'],
#  ('closes,', 'another', 'opens,'): ['but'],
#  ('another', 'opens,', 'but'): ['often'],
#  ('opens,', 'but', 'often'): ['we'],
#  ...}
